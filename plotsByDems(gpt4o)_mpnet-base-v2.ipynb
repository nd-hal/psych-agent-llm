# %% [markdown]
# ## Plot by Demographics
#
# Inspired by https://arxiv.org/abs/2410.19599

# %%
import pandas as pd

# %%
Dsim = pd.read_csv("similarity_calculations_4o_all_sbert_all-mpnet-base-v2.csv")

Dsim.head()
# Out:
#    Unnamed: 0  Sample Index                  Condition            Question  \
# 0           0             0                all_4.jsonl  Text_SubjectiveLit
# 1           1             0                all_4.jsonl        Text_Anxiety
# 2           2             0                all_4.jsonl       Text_Numeracy
# 3           3             0                all_4.jsonl      Text_TrustPhys
# 4           4             0  conditioning_on_all.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.146102  I feel fairly confident in my ability to obtai...
# 1    0.489447  When I visit the doctor's office, I sometimes ...
# 2    0.104984  Sure, there was a time when a close friend was...
# 3    0.546169  I generally trust my primary care physician be...
# 4    0.142502  I feel quite confident in my ability to obtain...
#
#                                           True Label
# 0  Life is great and we all must pick what we wan...
# 1  How doctors decide to take care of uses and pr...
# 2  The girl I'm engaged to has health problems at...
# 3  Doctors and nurses ppl must have full trust in...
# 4  Life is great and we all must pick what we wan...

# %%
from utils import *
EXPERIMENT_TYPE = 'Demographic + Behavioral + Psychological'
file_path = 'Data/Data_SurveyPlusDemographics.txt'
data = pd.read_csv(file_path, sep='\t', encoding='ISO-8859-1')

# Data preprocess
data, psychological_list = convert_to_natural_language(data)
data, fipi_columns = split_fipi_responses(data)
data.drop(columns=['FIPI_response'], inplace=True, errors='ignore')
psychological_list.extend(fipi_columns)


train_data = select_experiment_data(data, EXPERIMENT_TYPE)
train_data = process_data_based_on_experiment(train_data, EXPERIMENT_TYPE)

# add labels column
label_columns = ['Text_SubjectiveLit', 'Text_Anxiety', 'Text_Numeracy', 'Text_TrustPhys']
train_data = pd.concat([train_data, data[label_columns]], axis=1)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_17936\1438049294.py:4: DtypeWarning: Columns (115) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, sep='\t', encoding='ISO-8859-1')
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])

# %%
train_data.head()
# Out:
#      D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8     HC_1     HC_2  ...  \
# 0  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152    Agree    Agree  ...
# 1  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150    Agree    Agree  ...
# 2  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160  Neutral  Neutral  ...
# 3  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168  Neutral  Neutral  ...
# 4  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220    Agree    Agree  ...
#
#       HC_5                                    FIPI_1_response  \
# 0  Neutral  You disagree that you are extraverted and enth...
# 1    Agree  You unknown that you are extraverted and enthu...
# 2  Neutral  You strongly agree that you are extraverted an...
# 3  Neutral  You disagree that you are extraverted and enth...
# 4  Neutral  You disagree that you are extraverted and enth...
#
#                                      FIPI_2_response  \
# 0  You strongly agree that you are agreeable and ...
# 1       You unknown that you are agreeable and kind.
# 2       You unknown that you are agreeable and kind.
# 3       You unknown that you are agreeable and kind.
# 4       You unknown that you are agreeable and kind.
#
#                                      FIPI_3_response  \
# 0  You strongly agree that you are dependable and...
# 1  You unknown that you are dependable and organi...
# 2  You unknown that you are dependable and organi...
# 3  You unknown that you are dependable and organi...
# 4  You unknown that you are dependable and organi...
#
#                                      FIPI_4_response  \
# 0  You unknown that you are emotionally stable an...
# 1  You strongly agree that you are emotionally st...
# 2  You unknown that you are emotionally stable an...
# 3  You agree that you are emotionally stable and ...
# 4  You agree that you are emotionally stable and ...
#
#                                      FIPI_5_response  \
# 0  You unknown that you are open to experience an...
# 1  You agree that you are open to experience and ...
# 2  You unknown that you are open to experience an...
# 3  You unknown that you are open to experience an...
# 4  You unknown that you are open to experience an...
#
#                                   Text_SubjectiveLit  \
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...
#
#                                         Text_Anxiety  \
# 0  With some health care providers in the past, I...
# 1  I worry that I won't get the full attention of...
# 2  I do not like to wait for test results to say ...
# 3  The thing that makes me most anxious is wonder...
# 4  I just get nervous having to sit in doctor's o...
#
#                                        Text_Numeracy  \
# 0  A friend had been given antibiotic eye drops f...
# 1  Just normal doctor visits and testing.  not wo...
# 2  I tried to use my math skills the best that I ...
# 3  I studied athletic training in college, and I'...
# 4  Every time I researched my symptoms myself and...
#
#                                       Text_TrustPhys
# 0  She never seems rushed with me, and she will a...
# 1  My doctor wants to give his all, but the time ...
# 2  I like that the dr takes the time to listen an...
# 3  Typically when I see a doctor, they are a medi...
# 4  I trust my doctor because he is highly trained...
#
# [5 rows x 22 columns]

# %%
train_data.columns
# Out:
# Index(['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'Dmed_7', 'Dmed_8', 'HC_1', 'HC_2',
#        'HC_3', 'HC_4', 'HC_5', 'FIPI_1_response', 'FIPI_2_response',
#        'FIPI_3_response', 'FIPI_4_response', 'FIPI_5_response',
#        'Text_SubjectiveLit', 'Text_Anxiety', 'Text_Numeracy',
#        'Text_TrustPhys'],
#       dtype='object')

# %%
Dtrain = train_data[["D1", "D2","D3","D4","D5","D6","Dmed_7","Dmed_8","Text_SubjectiveLit", "Text_Anxiety", "Text_Numeracy","Text_TrustPhys"]]
Dtrain["id"] = Dtrain.index

Dtrain.head()
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_17936\3733813787.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dtrain["id"] = Dtrain.index
#      D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 1  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150
# 2  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160
# 3  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168
# 4  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220
#
#                                   Text_SubjectiveLit  \
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...
#
#                                         Text_Anxiety  \
# 0  With some health care providers in the past, I...
# 1  I worry that I won't get the full attention of...
# 2  I do not like to wait for test results to say ...
# 3  The thing that makes me most anxious is wonder...
# 4  I just get nervous having to sit in doctor's o...
#
#                                        Text_Numeracy  \
# 0  A friend had been given antibiotic eye drops f...
# 1  Just normal doctor visits and testing.  not wo...
# 2  I tried to use my math skills the best that I ...
# 3  I studied athletic training in college, and I'...
# 4  Every time I researched my symptoms myself and...
#
#                                       Text_TrustPhys  id
# 0  She never seems rushed with me, and she will a...   0
# 1  My doctor wants to give his all, but the time ...   1
# 2  I like that the dr takes the time to listen an...   2
# 3  Typically when I see a doctor, they are a medi...   3
# 4  I trust my doctor because he is highly trained...   4

# %%
Dtrainlong = pd.wide_to_long(Dtrain, "Text_", i="id", j="topic", suffix="\D+").reset_index()

Dtrainlong["topic"] = "Text_" + Dtrainlong["topic"].astype(str)

# %%
Dtrainlong.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 1   1  Text_SubjectiveLit  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150
# 2   2  Text_SubjectiveLit  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160
# 3   3  Text_SubjectiveLit  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168
# 4   4  Text_SubjectiveLit  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220
#
#                                                Text_
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...

# %%
Dsim.head()
# Out:
#    Unnamed: 0  Sample Index                  Condition            Question  \
# 0           0             0                all_4.jsonl  Text_SubjectiveLit
# 1           1             0                all_4.jsonl        Text_Anxiety
# 2           2             0                all_4.jsonl       Text_Numeracy
# 3           3             0                all_4.jsonl      Text_TrustPhys
# 4           4             0  conditioning_on_all.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.146102  I feel fairly confident in my ability to obtai...
# 1    0.489447  When I visit the doctor's office, I sometimes ...
# 2    0.104984  Sure, there was a time when a close friend was...
# 3    0.546169  I generally trust my primary care physician be...
# 4    0.142502  I feel quite confident in my ability to obtain...
#
#                                           True Label
# 0  Life is great and we all must pick what we wan...
# 1  How doctors decide to take care of uses and pr...
# 2  The girl I'm engaged to has health problems at...
# 3  Doctors and nurses ppl must have full trust in...
# 4  Life is great and we all must pick what we wan...

# %%
D = Dtrainlong.merge(Dsim, left_on=["topic","Text_"], right_on=["Question","True Label"])

D.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 1   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 2   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 3   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 4   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
#
#                                                Text_  Unnamed: 0  \
# 0  I believe that I understand most of what my he...       63360
# 1  I believe that I understand most of what my he...       63364
# 2  I believe that I understand most of what my he...       63368
# 3  I believe that I understand most of what my he...       63372
# 4  I believe that I understand most of what my he...       63376
#
#    Sample Index                         Condition            Question  \
# 0          1980                       all_4.jsonl  Text_SubjectiveLit
# 1          1980         conditioning_on_all.jsonl  Text_SubjectiveLit
# 2          1980        holdout_Text_Anxiety.jsonl  Text_SubjectiveLit
# 3          1980       holdout_Text_Numeracy.jsonl  Text_SubjectiveLit
# 4          1980  holdout_Text_SubjectiveLit.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.752258  I feel quite capable of obtaining and understa...
# 1    0.639786  I feel quite confident in my ability to obtain...
# 2    0.697282  I feel quite confident in my ability to obtain...
# 3    0.740881  I feel fairly confident in my ability to obtai...
# 4    0.712256  I feel quite capable when it comes to obtainin...
#
#                                           True Label
# 0  I believe that I understand most of what my he...
# 1  I believe that I understand most of what my he...
# 2  I believe that I understand most of what my he...
# 3  I believe that I understand most of what my he...
# 4  I believe that I understand most of what my he...

# %%
# Set up the demographics based on our paper
#D["Age_bin"] = (D["D1"] <= 38).astype(int)
D["Age"] = (D["D1"] <= 32).astype(int)

D["Gender"] = (D["D2"] == 1).astype(int)
D["Race"] = (D["D3"] == 1).astype(int)
D["Education"] = (D["D4"] >= 5).astype(int)
D["Income"] = (D["D5"] >= 4).astype(int)

D.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  ...  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 1   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 2   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 3   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 4   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
#
#                           Condition            Question  Similarity  \
# 0                       all_4.jsonl  Text_SubjectiveLit    0.752258
# 1         conditioning_on_all.jsonl  Text_SubjectiveLit    0.639786
# 2        holdout_Text_Anxiety.jsonl  Text_SubjectiveLit    0.697282
# 3       holdout_Text_Numeracy.jsonl  Text_SubjectiveLit    0.740881
# 4  holdout_Text_SubjectiveLit.jsonl  Text_SubjectiveLit    0.712256
#
#                                   Generated Response  \
# 0  I feel quite capable of obtaining and understa...
# 1  I feel quite confident in my ability to obtain...
# 2  I feel quite confident in my ability to obtain...
# 3  I feel fairly confident in my ability to obtai...
# 4  I feel quite capable when it comes to obtainin...
#
#                                           True Label  Age Gender Race  \
# 0  I believe that I understand most of what my he...    1      0    1
# 1  I believe that I understand most of what my he...    1      0    1
# 2  I believe that I understand most of what my he...    1      0    1
# 3  I believe that I understand most of what my he...    1      0    1
# 4  I believe that I understand most of what my he...    1      0    1
#
#    Education  Income
# 0          1       0
# 1          1       0
# 2          1       0
# 3          1       0
# 4          1       0
#
# [5 rows x 23 columns]

# %%
D["Condition"] = D["Condition"].str.replace("json_datasets_200/", "")
D["Condition"] = D["Condition"].str.replace(".jsonl", "")
D["Condition"] = D["Condition"].str.replace("_Text_Anxiety", "")
D["Condition"] = D["Condition"].str.replace("_Text_Numeracy", "")
D["Condition"] = D["Condition"].str.replace("_Text_SubjectiveLit", "")
D["Condition"] = D["Condition"].str.replace("_Text_TrustPhys", "")
D.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  ...  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 1   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 2   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 3   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 4   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
#
#              Condition            Question  Similarity  \
# 0                all_4  Text_SubjectiveLit    0.752258
# 1  conditioning_on_all  Text_SubjectiveLit    0.639786
# 2              holdout  Text_SubjectiveLit    0.697282
# 3              holdout  Text_SubjectiveLit    0.740881
# 4              holdout  Text_SubjectiveLit    0.712256
#
#                                   Generated Response  \
# 0  I feel quite capable of obtaining and understa...
# 1  I feel quite confident in my ability to obtain...
# 2  I feel quite confident in my ability to obtain...
# 3  I feel fairly confident in my ability to obtai...
# 4  I feel quite capable when it comes to obtainin...
#
#                                           True Label  Age Gender Race  \
# 0  I believe that I understand most of what my he...    1      0    1
# 1  I believe that I understand most of what my he...    1      0    1
# 2  I believe that I understand most of what my he...    1      0    1
# 3  I believe that I understand most of what my he...    1      0    1
# 4  I believe that I understand most of what my he...    1      0    1
#
#    Education  Income
# 0          1       0
# 1          1       0
# 2          1       0
# 3          1       0
# 4          1       0
#
# [5 rows x 23 columns]

# %%
D.Age.describe()
# Out:
# count    266768.000000
# mean          0.709950
# std           0.453786
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: Age, dtype: float64

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Age', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   4.722608  2.395726e-06
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   5.456418  5.104997e-08
# 2   Text_SubjectiveLit              holdout  t-test  10.807664  3.796094e-27
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   6.992554  3.076479e-12
# 4   Text_SubjectiveLit     no_system_prompt  t-test   5.473212  4.647343e-08
# 5         Text_Anxiety                all_4  t-test   2.608734  9.117236e-03
# 6         Text_Anxiety  conditioning_on_all  t-test   5.393732  7.234708e-08
# 7         Text_Anxiety              holdout  t-test   8.890401  6.638944e-19
# 8         Text_Anxiety   Baseline Zero Shot  t-test   6.785150  1.304867e-11
# 9         Text_Anxiety     no_system_prompt  t-test   5.381856  7.733040e-08
# 10       Text_Numeracy                all_4  t-test   1.463521  1.433948e-01
# 11       Text_Numeracy  conditioning_on_all  t-test   5.539032  3.199654e-08
# 12       Text_Numeracy              holdout  t-test   5.375525  7.730490e-08
# 13       Text_Numeracy   Baseline Zero Shot  t-test   6.098361  1.157115e-09
# 14       Text_Numeracy     no_system_prompt  t-test   4.672931  3.052757e-06
# 15      Text_TrustPhys                all_4  t-test   4.582798  4.705136e-06
# 16      Text_TrustPhys  conditioning_on_all  t-test   5.137446  2.897999e-07
# 17      Text_TrustPhys              holdout  t-test   8.842252  1.019819e-18
# 18      Text_TrustPhys   Baseline Zero Shot  t-test   6.475619  1.040824e-10
# 19      Text_TrustPhys     no_system_prompt  t-test   5.102028  3.492257e-07
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10        False
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation



sns.displot(
    D, x="Similarity", hue="Race", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Race', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_17936\324857929.py:17: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Race', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Race', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   7.007241  2.726547e-12
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   4.087327  4.425194e-05
# 2   Text_SubjectiveLit              holdout  t-test  13.485819  2.778067e-41
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   4.860320  1.204639e-06
# 4   Text_SubjectiveLit     no_system_prompt  t-test   6.870134  7.127760e-12
# 5         Text_Anxiety                all_4  t-test   2.417720  1.564956e-02
# 6         Text_Anxiety  conditioning_on_all  t-test   1.831020  6.715057e-02
# 7         Text_Anxiety              holdout  t-test   4.154361  3.273993e-05
# 8         Text_Anxiety   Baseline Zero Shot  t-test   0.580612  5.615252e-01
# 9         Text_Anxiety     no_system_prompt  t-test   1.507026  1.318606e-01
# 10       Text_Numeracy                all_4  t-test   7.289282  3.520805e-13
# 11       Text_Numeracy  conditioning_on_all  t-test   1.320098  1.868568e-01
# 12       Text_Numeracy              holdout  t-test  12.002570  4.308504e-33
# 13       Text_Numeracy   Baseline Zero Shot  t-test   2.322417  2.024528e-02
# 14       Text_Numeracy     no_system_prompt  t-test   3.445159  5.748353e-04
# 15      Text_TrustPhys                all_4  t-test   0.168243  8.663981e-01
# 16      Text_TrustPhys  conditioning_on_all  t-test  -0.999412  3.176383e-01
# 17      Text_TrustPhys              holdout  t-test   0.636569  5.244124e-01
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -0.671902  5.016741e-01
# 19      Text_TrustPhys     no_system_prompt  t-test   0.386809  6.989130e-01
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6         False
# 7          True
# 8         False
# 9         False
# 10         True
# 11        False
# 12         True
# 13         True
# 14         True
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False

# %%
sns.displot(
    D, x="Similarity", hue="Age", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Age', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_17936\3306198146.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Age', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Age', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   4.722608  2.395726e-06
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   5.456418  5.104997e-08
# 2   Text_SubjectiveLit              holdout  t-test  10.807664  3.796094e-27
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   6.992554  3.076479e-12
# 4   Text_SubjectiveLit     no_system_prompt  t-test   5.473212  4.647343e-08
# 5         Text_Anxiety                all_4  t-test   2.608734  9.117236e-03
# 6         Text_Anxiety  conditioning_on_all  t-test   5.393732  7.234708e-08
# 7         Text_Anxiety              holdout  t-test   8.890401  6.638944e-19
# 8         Text_Anxiety   Baseline Zero Shot  t-test   6.785150  1.304867e-11
# 9         Text_Anxiety     no_system_prompt  t-test   5.381856  7.733040e-08
# 10       Text_Numeracy                all_4  t-test   1.463521  1.433948e-01
# 11       Text_Numeracy  conditioning_on_all  t-test   5.539032  3.199654e-08
# 12       Text_Numeracy              holdout  t-test   5.375525  7.730490e-08
# 13       Text_Numeracy   Baseline Zero Shot  t-test   6.098361  1.157115e-09
# 14       Text_Numeracy     no_system_prompt  t-test   4.672931  3.052757e-06
# 15      Text_TrustPhys                all_4  t-test   4.582798  4.705136e-06
# 16      Text_TrustPhys  conditioning_on_all  t-test   5.137446  2.897999e-07
# 17      Text_TrustPhys              holdout  t-test   8.842252  1.019819e-18
# 18      Text_TrustPhys   Baseline Zero Shot  t-test   6.475619  1.040824e-10
# 19      Text_TrustPhys     no_system_prompt  t-test   5.102028  3.492257e-07
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10        False
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True

# %%
sns.displot(
    D, x="Similarity", hue="Gender", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Gender', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_17936\3657184094.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Gender', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Gender', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   2.977018  2.923490e-03
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   3.115579  1.845151e-03
# 2   Text_SubjectiveLit              holdout  t-test   7.261689  3.951227e-13
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   2.955993  3.129992e-03
# 4   Text_SubjectiveLit     no_system_prompt  t-test   3.858568  1.153781e-04
# 5         Text_Anxiety                all_4  t-test   2.778523  5.479709e-03
# 6         Text_Anxiety  conditioning_on_all  t-test   0.851099  3.947527e-01
# 7         Text_Anxiety              holdout  t-test   4.409319  1.041984e-05
# 8         Text_Anxiety   Baseline Zero Shot  t-test   2.052104  4.020665e-02
# 9         Text_Anxiety     no_system_prompt  t-test   3.033703  2.427064e-03
# 10       Text_Numeracy                all_4  t-test   0.560550  5.751266e-01
# 11       Text_Numeracy  conditioning_on_all  t-test  -0.949664  3.423229e-01
# 12       Text_Numeracy              holdout  t-test   2.290813  2.198312e-02
# 13       Text_Numeracy   Baseline Zero Shot  t-test   0.300345  7.639248e-01
# 14       Text_Numeracy     no_system_prompt  t-test   0.664679  5.062820e-01
# 15      Text_TrustPhys                all_4  t-test   0.045857  9.634260e-01
# 16      Text_TrustPhys  conditioning_on_all  t-test  -0.423478  6.719631e-01
# 17      Text_TrustPhys              holdout  t-test  -0.698905  4.846189e-01
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -0.324283  7.457365e-01
# 19      Text_TrustPhys     no_system_prompt  t-test   0.253408  7.999626e-01
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6         False
# 7          True
# 8          True
# 9          True
# 10        False
# 11        False
# 12         True
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False

# %%
sns.displot(
    D, x="Similarity", hue="Education", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Education', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_17936\4058203010.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Education', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Education', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   5.865274  4.657963e-09
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   6.137587  8.765289e-10
# 2   Text_SubjectiveLit              holdout  t-test  12.263269  1.697334e-34
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   6.684593  2.466614e-11
# 4   Text_SubjectiveLit     no_system_prompt  t-test   6.879285  6.457056e-12
# 5         Text_Anxiety                all_4  t-test   3.603272  3.160889e-04
# 6         Text_Anxiety  conditioning_on_all  t-test   3.717826  2.022780e-04
# 7         Text_Anxiety              holdout  t-test   5.846854  5.056749e-09
# 8         Text_Anxiety   Baseline Zero Shot  t-test   3.932277  8.483261e-05
# 9         Text_Anxiety     no_system_prompt  t-test   3.636592  2.779508e-04
# 10       Text_Numeracy                all_4  t-test   1.357546  1.746449e-01
# 11       Text_Numeracy  conditioning_on_all  t-test  -2.142676  3.216817e-02
# 12       Text_Numeracy              holdout  t-test   2.489951  1.278095e-02
# 13       Text_Numeracy   Baseline Zero Shot  t-test   1.750386  8.008856e-02
# 14       Text_Numeracy     no_system_prompt  t-test  -0.280101  7.794069e-01
# 15      Text_TrustPhys                all_4  t-test   1.470665  1.414197e-01
# 16      Text_TrustPhys  conditioning_on_all  t-test   2.596435  9.436293e-03
# 17      Text_TrustPhys              holdout  t-test   3.566596  3.621572e-04
# 18      Text_TrustPhys   Baseline Zero Shot  t-test   2.692475  7.106634e-03
# 19      Text_TrustPhys     no_system_prompt  t-test   2.249200  2.452593e-02
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10        False
# 11         True
# 12         True
# 13        False
# 14        False
# 15        False
# 16         True
# 17         True
# 18         True
# 19         True

# %%
sns.displot(
    D, x="Similarity", hue="Income", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Income', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_17936\2664053132.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Income', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    mean1 = group1.mean()
    mean2 = group2.mean()
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value, mean1, mean2, groups[0], groups[1]

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value, mean1, mean2, group1_name, group2_name = perform_stat_test(
                subset, 'Income', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            higher_group = group1_name if mean1 > mean2 else group2_name
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant,
                'Mean_{}'.format(group1_name): mean1,
                'Mean_{}'.format(group2_name): mean2,
                'Higher_Mean_Group': higher_group if significant else 'N/A'
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")

results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic   p-value  \
# 0   Text_SubjectiveLit                all_4  t-test  -1.166053  0.243634
# 1   Text_SubjectiveLit  conditioning_on_all  t-test  -2.523656  0.011637
# 2   Text_SubjectiveLit              holdout  t-test  -2.570300  0.010166
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test  -1.997539  0.045808
# 4   Text_SubjectiveLit     no_system_prompt  t-test  -2.002670  0.045254
# 5         Text_Anxiety                all_4  t-test  -2.239899  0.025130
# 6         Text_Anxiety  conditioning_on_all  t-test  -3.377378  0.000736
# 7         Text_Anxiety              holdout  t-test  -3.922868  0.000088
# 8         Text_Anxiety   Baseline Zero Shot  t-test  -2.407501  0.016089
# 9         Text_Anxiety     no_system_prompt  t-test  -1.685139  0.092009
# 10       Text_Numeracy                all_4  t-test  -0.565349  0.571856
# 11       Text_Numeracy  conditioning_on_all  t-test   1.162362  0.245131
# 12       Text_Numeracy              holdout  t-test  -0.775934  0.437795
# 13       Text_Numeracy   Baseline Zero Shot  t-test  -1.429971  0.152773
# 14       Text_Numeracy     no_system_prompt  t-test  -0.386807  0.698911
# 15      Text_TrustPhys                all_4  t-test  -0.292890  0.769615
# 16      Text_TrustPhys  conditioning_on_all  t-test  -2.793416  0.005231
# 17      Text_TrustPhys              holdout  t-test  -2.148656  0.031671
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -1.919228  0.054999
# 19      Text_TrustPhys     no_system_prompt  t-test  -0.823876  0.410040
#
#     Significant    Mean_0    Mean_1 Higher_Mean_Group
# 0         False  0.645378  0.649488               N/A
# 1          True  0.578916  0.587732                 1
# 2          True  0.637720  0.642262                 1
# 3          True  0.609713  0.616639                 1
# 4          True  0.640969  0.647899                 1
# 5          True  0.595706  0.603978                 1
# 6          True  0.549884  0.561181                 1
# 7          True  0.579272  0.586376                 1
# 8          True  0.558452  0.566885                 1
# 9         False  0.572196  0.578173               N/A
# 10        False  0.359958  0.362010               N/A
# 11        False  0.293716  0.289993               N/A
# 12        False  0.352570  0.353944               N/A
# 13        False  0.297077  0.301529               N/A
# 14        False  0.353538  0.354869               N/A
# 15        False  0.682969  0.684107               N/A
# 16         True  0.619899  0.630709                 1
# 17         True  0.666306  0.670483                 1
# 18        False  0.616940  0.624267               N/A
# 19        False  0.659208  0.662355               N/A
