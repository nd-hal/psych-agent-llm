# %% [markdown]
# ## Plot by Demographics
#
# Inspired by https://arxiv.org/abs/2410.19599

# %%
import pandas as pd

# %%
Dsim = pd.read_csv("bert_sim_results_gpt.csv")

Dsim.head()
# Out:
#    Unnamed: 0  Sample Index                  Condition            Question  \
# 0           0             0                all_4.jsonl  Text_SubjectiveLit
# 1           1             0                all_4.jsonl        Text_Anxiety
# 2           2             0                all_4.jsonl       Text_Numeracy
# 3           3             0                all_4.jsonl      Text_TrustPhys
# 4           4             0  conditioning_on_all.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.932699  I believe I have a moderate capacity to obtain...
# 1    0.959319  I often worry that my concerns won't be taken ...
# 2    0.956563  As someone who values health, I've spent a lot...
# 3    0.984892  I have a general trust in doctors but my exper...
# 4    0.956202  I believe I have a fairly good capacity to obt...
#
#                                           True Label
# 0  I'm somewhat confident that I have the capacit...
# 1  When I'm extreme sick I'm just anxious about w...
# 2  A friend when to the ER for a certain thing, t...
# 3  I think they are more concerned about what is ...
# 4  I'm somewhat confident that I have the capacit...

# %%
from utils import *
EXPERIMENT_TYPE = 'Demographic + Behavioral + Psychological'
file_path = 'Data/Data_SurveyPlusDemographics.txt'
data = pd.read_csv(file_path, sep='\t', encoding='ISO-8859-1')

# Data preprocess
data, psychological_list = convert_to_natural_language(data)
data, fipi_columns = split_fipi_responses(data)
data.drop(columns=['FIPI_response'], inplace=True, errors='ignore')
psychological_list.extend(fipi_columns)


train_data = select_experiment_data(data, EXPERIMENT_TYPE)
train_data = process_data_based_on_experiment(train_data, EXPERIMENT_TYPE)

# add labels column
label_columns = ['Text_SubjectiveLit', 'Text_Anxiety', 'Text_Numeracy', 'Text_TrustPhys']
train_data = pd.concat([train_data, data[label_columns]], axis=1)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_14860\1438049294.py:4: DtypeWarning: Columns (115) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, sep='\t', encoding='ISO-8859-1')
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])

# %%
train_data.head()
# Out:
#      D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8     HC_1     HC_2  ...  \
# 0  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152    Agree    Agree  ...
# 1  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150    Agree    Agree  ...
# 2  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160  Neutral  Neutral  ...
# 3  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168  Neutral  Neutral  ...
# 4  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220    Agree    Agree  ...
#
#       HC_5                                    FIPI_1_response  \
# 0  Neutral  You disagree that you are extraverted and enth...
# 1    Agree  You unknown that you are extraverted and enthu...
# 2  Neutral  You strongly agree that you are extraverted an...
# 3  Neutral  You disagree that you are extraverted and enth...
# 4  Neutral  You disagree that you are extraverted and enth...
#
#                                      FIPI_2_response  \
# 0  You strongly agree that you are agreeable and ...
# 1       You unknown that you are agreeable and kind.
# 2       You unknown that you are agreeable and kind.
# 3       You unknown that you are agreeable and kind.
# 4       You unknown that you are agreeable and kind.
#
#                                      FIPI_3_response  \
# 0  You strongly agree that you are dependable and...
# 1  You unknown that you are dependable and organi...
# 2  You unknown that you are dependable and organi...
# 3  You unknown that you are dependable and organi...
# 4  You unknown that you are dependable and organi...
#
#                                      FIPI_4_response  \
# 0  You unknown that you are emotionally stable an...
# 1  You strongly agree that you are emotionally st...
# 2  You unknown that you are emotionally stable an...
# 3  You agree that you are emotionally stable and ...
# 4  You agree that you are emotionally stable and ...
#
#                                      FIPI_5_response  \
# 0  You unknown that you are open to experience an...
# 1  You agree that you are open to experience and ...
# 2  You unknown that you are open to experience an...
# 3  You unknown that you are open to experience an...
# 4  You unknown that you are open to experience an...
#
#                                   Text_SubjectiveLit  \
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...
#
#                                         Text_Anxiety  \
# 0  With some health care providers in the past, I...
# 1  I worry that I won't get the full attention of...
# 2  I do not like to wait for test results to say ...
# 3  The thing that makes me most anxious is wonder...
# 4  I just get nervous having to sit in doctor's o...
#
#                                        Text_Numeracy  \
# 0  A friend had been given antibiotic eye drops f...
# 1  Just normal doctor visits and testing.  not wo...
# 2  I tried to use my math skills the best that I ...
# 3  I studied athletic training in college, and I'...
# 4  Every time I researched my symptoms myself and...
#
#                                       Text_TrustPhys
# 0  She never seems rushed with me, and she will a...
# 1  My doctor wants to give his all, but the time ...
# 2  I like that the dr takes the time to listen an...
# 3  Typically when I see a doctor, they are a medi...
# 4  I trust my doctor because he is highly trained...
#
# [5 rows x 22 columns]

# %%
train_data.columns
# Out:
# Index(['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'Dmed_7', 'Dmed_8', 'HC_1', 'HC_2',
#        'HC_3', 'HC_4', 'HC_5', 'FIPI_1_response', 'FIPI_2_response',
#        'FIPI_3_response', 'FIPI_4_response', 'FIPI_5_response',
#        'Text_SubjectiveLit', 'Text_Anxiety', 'Text_Numeracy',
#        'Text_TrustPhys'],
#       dtype='object')

# %%
Dtrain = train_data[["D1", "D2","D3","D4","D5","D6","Dmed_7","Dmed_8","Text_SubjectiveLit", "Text_Anxiety", "Text_Numeracy","Text_TrustPhys"]]
Dtrain["id"] = Dtrain.index

Dtrain.head()
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_14860\3733813787.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dtrain["id"] = Dtrain.index
#      D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 1  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150
# 2  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160
# 3  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168
# 4  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220
#
#                                   Text_SubjectiveLit  \
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...
#
#                                         Text_Anxiety  \
# 0  With some health care providers in the past, I...
# 1  I worry that I won't get the full attention of...
# 2  I do not like to wait for test results to say ...
# 3  The thing that makes me most anxious is wonder...
# 4  I just get nervous having to sit in doctor's o...
#
#                                        Text_Numeracy  \
# 0  A friend had been given antibiotic eye drops f...
# 1  Just normal doctor visits and testing.  not wo...
# 2  I tried to use my math skills the best that I ...
# 3  I studied athletic training in college, and I'...
# 4  Every time I researched my symptoms myself and...
#
#                                       Text_TrustPhys  id
# 0  She never seems rushed with me, and she will a...   0
# 1  My doctor wants to give his all, but the time ...   1
# 2  I like that the dr takes the time to listen an...   2
# 3  Typically when I see a doctor, they are a medi...   3
# 4  I trust my doctor because he is highly trained...   4

# %%
Dtrainlong = pd.wide_to_long(Dtrain, "Text_", i="id", j="topic", suffix="\D+").reset_index()

Dtrainlong["topic"] = "Text_" + Dtrainlong["topic"].astype(str)

# %%
Dtrainlong.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 1   1  Text_SubjectiveLit  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150
# 2   2  Text_SubjectiveLit  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160
# 3   3  Text_SubjectiveLit  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168
# 4   4  Text_SubjectiveLit  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220
#
#                                                Text_
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...

# %%
Dsim.head()
# Out:
#    Unnamed: 0  Sample Index                  Condition            Question  \
# 0           0             0                all_4.jsonl  Text_SubjectiveLit
# 1           1             0                all_4.jsonl        Text_Anxiety
# 2           2             0                all_4.jsonl       Text_Numeracy
# 3           3             0                all_4.jsonl      Text_TrustPhys
# 4           4             0  conditioning_on_all.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.932699  I believe I have a moderate capacity to obtain...
# 1    0.959319  I often worry that my concerns won't be taken ...
# 2    0.956563  As someone who values health, I've spent a lot...
# 3    0.984892  I have a general trust in doctors but my exper...
# 4    0.956202  I believe I have a fairly good capacity to obt...
#
#                                           True Label
# 0  I'm somewhat confident that I have the capacit...
# 1  When I'm extreme sick I'm just anxious about w...
# 2  A friend when to the ER for a certain thing, t...
# 3  I think they are more concerned about what is ...
# 4  I'm somewhat confident that I have the capacit...

# %%
D = Dtrainlong.merge(Dsim, left_on=["topic","Text_"], right_on=["Question","True Label"])

D.head()
# Out:
#     id               topic   D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184
# 1  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184
# 2  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184
# 3  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184
# 4  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184
#
#                                                Text_  Unnamed: 0  \
# 0  I'm somewhat confident that I have the capacit...           0
# 1  I'm somewhat confident that I have the capacit...           4
# 2  I'm somewhat confident that I have the capacit...           8
# 3  I'm somewhat confident that I have the capacit...          12
# 4  I'm somewhat confident that I have the capacit...          16
#
#    Sample Index                         Condition            Question  \
# 0             0                       all_4.jsonl  Text_SubjectiveLit
# 1             0         conditioning_on_all.jsonl  Text_SubjectiveLit
# 2             0        holdout_Text_Anxiety.jsonl  Text_SubjectiveLit
# 3             0       holdout_Text_Numeracy.jsonl  Text_SubjectiveLit
# 4             0  holdout_Text_SubjectiveLit.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.932699  I believe I have a moderate capacity to obtain...
# 1    0.956202  I believe I have a fairly good capacity to obt...
# 2    0.918915  I would say I have a moderate capacity to obta...
# 3    0.934726  I feel quite capable of understanding basic he...
# 4    0.952683  I feel very comfortable obtaining, processing,...
#
#                                           True Label
# 0  I'm somewhat confident that I have the capacit...
# 1  I'm somewhat confident that I have the capacit...
# 2  I'm somewhat confident that I have the capacit...
# 3  I'm somewhat confident that I have the capacit...
# 4  I'm somewhat confident that I have the capacit...

# %%
# Set up the demographics based on our paper
#D["Age_bin"] = (D["D1"] <= 38).astype(int)
D["Age"] = (D["D1"] <= 32).astype(int)

D["Gender"] = (D["D2"] == 1).astype(int)
D["Race"] = (D["D3"] == 1).astype(int)
D["Education"] = (D["D4"] >= 5).astype(int)
D["Income"] = (D["D5"] >= 4).astype(int)

D.head()
# Out:
#     id               topic   D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  ...  \
# 0  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
# 1  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
# 2  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
# 3  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
# 4  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
#
#                           Condition            Question  Similarity  \
# 0                       all_4.jsonl  Text_SubjectiveLit    0.932699
# 1         conditioning_on_all.jsonl  Text_SubjectiveLit    0.956202
# 2        holdout_Text_Anxiety.jsonl  Text_SubjectiveLit    0.918915
# 3       holdout_Text_Numeracy.jsonl  Text_SubjectiveLit    0.934726
# 4  holdout_Text_SubjectiveLit.jsonl  Text_SubjectiveLit    0.952683
#
#                                   Generated Response  \
# 0  I believe I have a moderate capacity to obtain...
# 1  I believe I have a fairly good capacity to obt...
# 2  I would say I have a moderate capacity to obta...
# 3  I feel quite capable of understanding basic he...
# 4  I feel very comfortable obtaining, processing,...
#
#                                           True Label  Age Gender Race  \
# 0  I'm somewhat confident that I have the capacit...    1      0    0
# 1  I'm somewhat confident that I have the capacit...    1      0    0
# 2  I'm somewhat confident that I have the capacit...    1      0    0
# 3  I'm somewhat confident that I have the capacit...    1      0    0
# 4  I'm somewhat confident that I have the capacit...    1      0    0
#
#    Education  Income
# 0          1       0
# 1          1       0
# 2          1       0
# 3          1       0
# 4          1       0
#
# [5 rows x 23 columns]

# %%
D["Condition"] = D["Condition"].str.replace("json_datasets_200/", "")
D["Condition"] = D["Condition"].str.replace(".jsonl", "")
D["Condition"] = D["Condition"].str.replace("_Text_Anxiety", "")
D["Condition"] = D["Condition"].str.replace("_Text_Numeracy", "")
D["Condition"] = D["Condition"].str.replace("_Text_SubjectiveLit", "")
D["Condition"] = D["Condition"].str.replace("_Text_TrustPhys", "")
D.head()
# Out:
#     id               topic   D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  ...  \
# 0  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
# 1  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
# 2  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
# 3  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
# 4  457  Text_SubjectiveLit  8.0  2.0  2.0  5.0  2.0  1.0    24.0    184  ...
#
#              Condition            Question  Similarity  \
# 0                all_4  Text_SubjectiveLit    0.932699
# 1  conditioning_on_all  Text_SubjectiveLit    0.956202
# 2              holdout  Text_SubjectiveLit    0.918915
# 3              holdout  Text_SubjectiveLit    0.934726
# 4              holdout  Text_SubjectiveLit    0.952683
#
#                                   Generated Response  \
# 0  I believe I have a moderate capacity to obtain...
# 1  I believe I have a fairly good capacity to obt...
# 2  I would say I have a moderate capacity to obta...
# 3  I feel quite capable of understanding basic he...
# 4  I feel very comfortable obtaining, processing,...
#
#                                           True Label  Age Gender Race  \
# 0  I'm somewhat confident that I have the capacit...    1      0    0
# 1  I'm somewhat confident that I have the capacit...    1      0    0
# 2  I'm somewhat confident that I have the capacit...    1      0    0
# 3  I'm somewhat confident that I have the capacit...    1      0    0
# 4  I'm somewhat confident that I have the capacit...    1      0    0
#
#    Education  Income
# 0          1       0
# 1          1       0
# 2          1       0
# 3          1       0
# 4          1       0
#
# [5 rows x 23 columns]

# %%
D.Age.describe()
# Out:
# count    960.000000
# mean       0.766667
# std        0.423173
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Age, dtype: float64

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Age', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic   p-value  \
# 0   Text_SubjectiveLit                all_4  t-test  -0.483975  0.637597
# 1   Text_SubjectiveLit  conditioning_on_all  t-test  -2.722086  0.011256
# 2   Text_SubjectiveLit              holdout  t-test  -3.044160  0.003091
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test  -0.499398  0.624449
# 4   Text_SubjectiveLit     no_system_prompt  t-test  -1.488346  0.155196
# 5         Text_Anxiety                all_4  t-test   2.067292  0.067803
# 6         Text_Anxiety  conditioning_on_all  t-test   1.740349  0.113066
# 7         Text_Anxiety              holdout  t-test   2.739562  0.008737
# 8         Text_Anxiety   Baseline Zero Shot  t-test   1.097033  0.301941
# 9         Text_Anxiety     no_system_prompt  t-test   1.501294  0.170322
# 10       Text_Numeracy                all_4  t-test  -0.577717  0.568117
# 11       Text_Numeracy  conditioning_on_all  t-test  -1.460682  0.157075
# 12       Text_Numeracy              holdout  t-test  -2.514370  0.013277
# 13       Text_Numeracy   Baseline Zero Shot  t-test  -2.356310  0.026401
# 14       Text_Numeracy     no_system_prompt  t-test  -1.703694  0.099565
# 15      Text_TrustPhys                all_4  t-test  -1.494794  0.146509
# 16      Text_TrustPhys  conditioning_on_all  t-test  -0.935110  0.360297
# 17      Text_TrustPhys              holdout  t-test  -2.075104  0.040176
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -0.226642  0.823077
# 19      Text_TrustPhys     no_system_prompt  t-test  -0.974474  0.338909
#
#     Significant
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
# 5         False
# 6         False
# 7          True
# 8         False
# 9         False
# 10        False
# 11        False
# 12         True
# 13         True
# 14        False
# 15        False
# 16        False
# 17         True
# 18        False
# 19        False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation



sns.displot(
    D, x="Similarity", hue="Race", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.8, 1.0)
plt.legend([0,1], title='Race', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_14860\3331570191.py:17: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Race', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Race', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic   p-value  \
# 0   Text_SubjectiveLit                all_4  t-test  -0.374461  0.711186
# 1   Text_SubjectiveLit  conditioning_on_all  t-test  -1.613597  0.117855
# 2   Text_SubjectiveLit              holdout  t-test  -2.707564  0.007785
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test  -0.615571  0.543192
# 4   Text_SubjectiveLit     no_system_prompt  t-test  -1.341938  0.191233
# 5         Text_Anxiety                all_4  t-test  -0.114252  0.909906
# 6         Text_Anxiety  conditioning_on_all  t-test  -0.637906  0.529242
# 7         Text_Anxiety              holdout  t-test  -0.622700  0.534939
# 8         Text_Anxiety   Baseline Zero Shot  t-test  -0.726102  0.474121
# 9         Text_Anxiety     no_system_prompt  t-test  -0.694053  0.493445
# 10       Text_Numeracy                all_4  t-test   0.784223  0.447317
# 11       Text_Numeracy  conditioning_on_all  t-test   0.493512  0.629934
# 12       Text_Numeracy              holdout  t-test   1.891211  0.063845
# 13       Text_Numeracy   Baseline Zero Shot  t-test   0.733834  0.476402
# 14       Text_Numeracy     no_system_prompt  t-test   0.868322  0.399438
# 15      Text_TrustPhys                all_4  t-test  -0.533950  0.597940
# 16      Text_TrustPhys  conditioning_on_all  t-test  -0.289431  0.774451
# 17      Text_TrustPhys              holdout  t-test  -1.211211  0.228404
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -0.181024  0.858079
# 19      Text_TrustPhys     no_system_prompt  t-test  -0.852809  0.403078
#
#     Significant
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False

# %%
sns.displot(
    D, x="Similarity", hue="Age", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.8, 1.0)
plt.legend([0,1], title='Age', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_26156\834092141.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Age', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Age', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic   p-value  \
# 0   Text_SubjectiveLit                all_4  t-test  -0.483975  0.637597
# 1   Text_SubjectiveLit  conditioning_on_all  t-test  -2.722086  0.011256
# 2   Text_SubjectiveLit              holdout  t-test  -3.044160  0.003091
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test  -0.499398  0.624449
# 4   Text_SubjectiveLit     no_system_prompt  t-test  -1.488346  0.155196
# 5         Text_Anxiety                all_4  t-test   2.067292  0.067803
# 6         Text_Anxiety  conditioning_on_all  t-test   1.740349  0.113066
# 7         Text_Anxiety              holdout  t-test   2.739562  0.008737
# 8         Text_Anxiety   Baseline Zero Shot  t-test   1.097033  0.301941
# 9         Text_Anxiety     no_system_prompt  t-test   1.501294  0.170322
# 10       Text_Numeracy                all_4  t-test  -0.577717  0.568117
# 11       Text_Numeracy  conditioning_on_all  t-test  -1.460682  0.157075
# 12       Text_Numeracy              holdout  t-test  -2.514370  0.013277
# 13       Text_Numeracy   Baseline Zero Shot  t-test  -2.356310  0.026401
# 14       Text_Numeracy     no_system_prompt  t-test  -1.703694  0.099565
# 15      Text_TrustPhys                all_4  t-test  -1.494794  0.146509
# 16      Text_TrustPhys  conditioning_on_all  t-test  -0.935110  0.360297
# 17      Text_TrustPhys              holdout  t-test  -2.075104  0.040176
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -0.226642  0.823077
# 19      Text_TrustPhys     no_system_prompt  t-test  -0.974474  0.338909
#
#     Significant
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
# 5         False
# 6         False
# 7          True
# 8         False
# 9         False
# 10        False
# 11        False
# 12         True
# 13         True
# 14        False
# 15        False
# 16        False
# 17         True
# 18        False
# 19        False

# %%
sns.displot(
    D, x="Similarity", hue="Gender", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.8, 1.0)
plt.legend([0,1], title='Gender', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_26156\2035089817.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Gender', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Gender', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic   p-value  \
# 0   Text_SubjectiveLit                all_4  t-test  -0.172732  0.866261
# 1   Text_SubjectiveLit  conditioning_on_all  t-test  -1.981345  0.063805
# 2   Text_SubjectiveLit              holdout  t-test  -2.517736  0.014404
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   0.018864  0.985313
# 4   Text_SubjectiveLit     no_system_prompt  t-test  -0.657723  0.523083
# 5         Text_Anxiety                all_4  t-test  -0.659135  0.518865
# 6         Text_Anxiety  conditioning_on_all  t-test  -1.053158  0.304061
# 7         Text_Anxiety              holdout  t-test  -1.632038  0.106481
# 8         Text_Anxiety   Baseline Zero Shot  t-test  -0.743210  0.467100
# 9         Text_Anxiety     no_system_prompt  t-test  -1.110877  0.278635
# 10       Text_Numeracy                all_4  t-test  -1.809663  0.081655
# 11       Text_Numeracy  conditioning_on_all  t-test  -1.398510  0.173318
# 12       Text_Numeracy              holdout  t-test  -2.090464  0.039101
# 13       Text_Numeracy   Baseline Zero Shot  t-test  -0.925840  0.362520
# 14       Text_Numeracy     no_system_prompt  t-test  -0.201227  0.842880
# 15      Text_TrustPhys                all_4  t-test  -0.489083  0.630870
# 16      Text_TrustPhys  conditioning_on_all  t-test  -0.662614  0.515574
# 17      Text_TrustPhys              holdout  t-test  -2.576809  0.011360
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -1.400829  0.172612
# 19      Text_TrustPhys     no_system_prompt  t-test  -1.093630  0.284172
#
#     Significant
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12         True
# 13        False
# 14        False
# 15        False
# 16        False
# 17         True
# 18        False
# 19        False

# %%
sns.displot(
    D, x="Similarity", hue="Education", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.8, 1.0)
plt.legend([0,1], title='Education', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_26156\96540991.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Education', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Education', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic   p-value  \
# 0   Text_SubjectiveLit                all_4  t-test  -0.238411  0.813659
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   0.815013  0.422136
# 2   Text_SubjectiveLit              holdout  t-test   0.262309  0.793569
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test  -0.384767  0.703364
# 4   Text_SubjectiveLit     no_system_prompt  t-test   0.825128  0.416322
# 5         Text_Anxiety                all_4  t-test  -0.118119  0.906978
# 6         Text_Anxiety  conditioning_on_all  t-test  -0.405828  0.688732
# 7         Text_Anxiety              holdout  t-test   0.316899  0.751894
# 8         Text_Anxiety   Baseline Zero Shot  t-test   0.294586  0.770619
# 9         Text_Anxiety     no_system_prompt  t-test  -0.643039  0.528825
# 10       Text_Numeracy                all_4  t-test   1.015345  0.321981
# 11       Text_Numeracy  conditioning_on_all  t-test   1.091215  0.285829
# 12       Text_Numeracy              holdout  t-test   2.330253  0.021807
# 13       Text_Numeracy   Baseline Zero Shot  t-test   2.029082  0.056396
# 14       Text_Numeracy     no_system_prompt  t-test   0.480931  0.634332
# 15      Text_TrustPhys                all_4  t-test   1.028230  0.314657
# 16      Text_TrustPhys  conditioning_on_all  t-test   1.514161  0.143864
# 17      Text_TrustPhys              holdout  t-test   1.303344  0.195275
# 18      Text_TrustPhys   Baseline Zero Shot  t-test   1.067947  0.295244
# 19      Text_TrustPhys     no_system_prompt  t-test   1.272327  0.214415
#
#     Significant
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12         True
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False

# %%
sns.displot(
    D, x="Similarity", hue="Income", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.8, 1.0)
plt.legend([0,1], title='Income', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_26156\2959827387.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Income', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    mean1 = group1.mean()
    mean2 = group2.mean()
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value, mean1, mean2, groups[0], groups[1]

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value, mean1, mean2, group1_name, group2_name = perform_stat_test(
                subset, 'Income', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            higher_group = group1_name if mean1 > mean2 else group2_name
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant,
                'Mean_{}'.format(group1_name): mean1,
                'Mean_{}'.format(group2_name): mean2,
                'Higher_Mean_Group': higher_group if significant else 'N/A'
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")

results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic   p-value  \
# 0   Text_SubjectiveLit                all_4  t-test  -0.074730  0.941886
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   1.164433  0.269244
# 2   Text_SubjectiveLit              holdout  t-test   1.434616  0.158225
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   0.885318  0.401808
# 4   Text_SubjectiveLit     no_system_prompt  t-test   0.971297  0.356751
# 5         Text_Anxiety                all_4  t-test  -0.295097  0.773146
# 6         Text_Anxiety  conditioning_on_all  t-test  -0.470702  0.646192
# 7         Text_Anxiety              holdout  t-test  -0.713966  0.477990
# 8         Text_Anxiety   Baseline Zero Shot  t-test  -0.553567  0.589463
# 9         Text_Anxiety     no_system_prompt  t-test  -0.460745  0.653103
# 10       Text_Numeracy                all_4  t-test  -1.161506  0.256145
# 11       Text_Numeracy  conditioning_on_all  t-test  -1.074334  0.293659
# 12       Text_Numeracy              holdout  t-test  -2.350977  0.020469
# 13       Text_Numeracy   Baseline Zero Shot  t-test  -1.065172  0.296538
# 14       Text_Numeracy     no_system_prompt  t-test   0.099792  0.921816
# 15      Text_TrustPhys                all_4  t-test  -0.119765  0.906700
# 16      Text_TrustPhys  conditioning_on_all  t-test  -0.607387  0.549867
# 17      Text_TrustPhys              holdout  t-test  -0.618462  0.538515
# 18      Text_TrustPhys   Baseline Zero Shot  t-test   0.186894  0.853954
# 19      Text_TrustPhys     no_system_prompt  t-test  -0.912132  0.375592
#
#     Significant    Mean_0    Mean_1 Higher_Mean_Group
# 0         False  0.976332  0.976889               N/A
# 1         False  0.976065  0.966524               N/A
# 2         False  0.976326  0.971131               N/A
# 3         False  0.974413  0.965364               N/A
# 4         False  0.974610  0.964749               N/A
# 5         False  0.940921  0.946642               N/A
# 6         False  0.944032  0.952355               N/A
# 7         False  0.942281  0.948367               N/A
# 8         False  0.926600  0.938682               N/A
# 9         False  0.941289  0.948956               N/A
# 10        False  0.954088  0.968924               N/A
# 11        False  0.952302  0.964765               N/A
# 12         True  0.954192  0.969307                 1
# 13        False  0.948605  0.962715               N/A
# 14        False  0.955214  0.953480               N/A
# 15        False  0.961647  0.963215               N/A
# 16        False  0.959651  0.965981               N/A
# 17        False  0.967044  0.969962               N/A
# 18        False  0.963258  0.961334               N/A
# 19        False  0.963933  0.972733               N/A
