# %%
#all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from sklearn.preprocessing import OneHotEncoder
from umap import UMAP
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import os
import seaborn as sns
from sklearn.model_selection import train_test_split
import json
from collections import defaultdict

from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from openai import OpenAI

best_k = 3 #change for different case


Text_Numeracy = "In a few sentences, please describe an experience in your life that demonstrated your knowledge of health or medical issues."
Text_Anxiety = "In a few sentences, please describe what makes you feel most anxious or worried when visiting the doctor's office."
Text_TrustPhys = "In a few sentences, please explain the reasons why you trust or distrust your primary care physician. If you do not have a primary care physician, please answer in regard to doctors in general."
Text_SubjectiveLit = "Regarding all the questions you just answered, to what degree do you feel you have the capacity to obtain, process, and understand basic health information and services needed to make appropriate health decisions? Please explain your answer in a few sentences."

# %% [markdown]
# ## Table for demographic/behavioral/psychological features

# %%
# 文件路径
file_path = 'Data\Data_SurveyPlusDemographics.txt'

# 读取文件
data = pd.read_csv(file_path, sep='\t', encoding='ISO-8859-1')

data = data.dropna()

# Display the remaining number of rows after dropping missing values
remaining_rows = data.shape[0]
print(f'Remaining number of rows after dropping missing values: {remaining_rows}')

# 显示数据的前几行
print(data.head())
# Out:
# Remaining number of rows after dropping missing values: 8120
#    File  Row   Q1   Q2   Q3  Q4  FQ1  FQ2  FQ3  ComQ1  ...   D6  Dmed_7  \
# 0     1    1  5.0  5.0  4.0   5  3.0  1.0    3    1.0  ...  1.0    30.0
# 1     1    2  4.0  4.0  4.0   4  3.0  1.0    3    2.0  ...  1.0    29.0
# 2     1    3  5.0  5.0  4.0   4  3.0  1.0    3    1.0  ...  1.0    32.0
# 3     1    4  5.0  5.0  4.0   4  3.0  4.0    3    1.0  ...  1.0    31.0
# 4     1    5  5.0  5.0  5.0   5  3.0  1.0    3    1.0  ...  1.0    34.0
#
#    Dmed_8 DMed_1  DMed_2  DMed_3  DMed_9  Dmed_10  Dmed_5  Dmed_6
# 0     152    4.0     1.0     4.0     3.0      5.0     1.0     1.0
# 1     150    3.0     1.0     8.0     3.0      6.0     1.0     1.0
# 2     160    1.0     1.0     4.0     6.0      5.0     1.0     1.0
# 3     168    5.0     1.0    12.0     2.0      5.0     1.0     3.0
# 4     220    5.0     1.0    12.0     3.0      4.0     7.0    15.0
#
# [5 rows x 123 columns]
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\533319393.py:5: DtypeWarning: Columns (115) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, sep='\t', encoding='ISO-8859-1')

# %%
demographic_list = [
    "D1",
    "D2",
    "D3",
    "D4",
    "D5",
    "D6",
    "Dmed_7",
    "Dmed_8"
]


behavioral_list  = [
    "DMed_1",
    "DMed_2",
    "DMed_3",
    "DMed_9",
    "Dmed_10",
    "Dmed_5",
    "Dmed_6",
    "HC_1",
    "HC_2",
    "HC_3",
    "HC_4",
    "HC_5",
    "Rx2"
]



psychological_list = [
    "ATQ_1",
    "ATQ_2",
    "ATQ_3",
    "ATQ_4",
    "ATQ_5",
    "ATQ_6",
    "ATQ_7",
    "ATQ_8",
    "TWB_1",
    "TWB_2",
    "TWB_3",
    "TWB_4",
    "TWB_5",
    "TWB_6",
    "TWB_7",
    "TWB_8",
    "TWB_9",
    "TWB_10",
    "RA1_1",
    "RA1_2",
    "RA1_3",
    "RA1_4",
    "RA1_5",
    "RA1_6",
    "RA1_7",
    "RA1_8",
    "RA1_9",
    "RA1_10",
    "STAI_1",
    "STAI_2",
    "STAI_3",
    "STAI_4",
    "STAI_5",
    "STAI_6",
    "STAI_7",
    "BSCS_1",
    "BSCS_2",
    "BSCS_3",
    "BSCS_4",
    "REI_1",
    "REI_2",
    "REI_3",
    "REI_4",
    "REI_5",
    "REI_6",
    "REI_7",
    "REI_8",
    "REI_9",
    "REI_10",
    "FIPI_1",
    "FIPI_2",
    "FIPI_3",
    "FIPI_4",
    "FIPI_5"
]

label_list = [
    "Text_Numeracy",
    "Text_Anxiety",
    "Text_TrustPhys",
    "Text_SubjectiveLit"
]


demographic_data = data[demographic_list]
behavioral_data = data[behavioral_list]
psychological_data = data[psychological_list]
labels = data[label_list]

# %%
train_data = data[demographic_list + behavioral_list]

# %%
import pandas as pd
import re


# 定义一个函数来清理数值数据
def clean_numeric(value):
    if isinstance(value, str):
        # 使用正则表达式提取数值部分
        numeric_value = re.findall(r'\d+', value)
        if numeric_value:
            return float(numeric_value[0])
        else:
            return None
    return value

# 清理数据，将所有列转换为数值类型
for column in train_data.columns:
    train_data[column] = train_data[column].apply(clean_numeric)

# 将数据转换为浮点型
train_data = train_data.astype(float)

# 获取第一行数据
first_row = train_data.iloc[0]

# 按列名、数据类型和内容分别打印
for column_name in train_data.columns:
    value = first_row[column_name]
    dtype = train_data[column_name].dtype
    print(f"{column_name} (Type: {dtype}): {value}")

# 检查清理后的数据
print(train_data.head())
# Out:
# D1 (Type: float64): 21.0
# D2 (Type: float64): 2.0
# D3 (Type: float64): 1.0
# D4 (Type: float64): 6.0
# D5 (Type: float64): 1.0
# D6 (Type: float64): 1.0
# Dmed_7 (Type: float64): 30.0
# Dmed_8 (Type: float64): 152.0
# DMed_1 (Type: float64): 4.0
# DMed_2 (Type: float64): 1.0
# DMed_3 (Type: float64): 4.0
# DMed_9 (Type: float64): 3.0
# Dmed_10 (Type: float64): 5.0
# Dmed_5 (Type: float64): 1.0
# Dmed_6 (Type: float64): 1.0
# HC_1 (Type: float64): 5.0
# HC_2 (Type: float64): 5.0
# HC_3 (Type: float64): 5.0
# HC_4 (Type: float64): 5.0
# HC_5 (Type: float64): 4.0
# Rx2 (Type: float64): 4.0
#      D1   D2   D3   D4   D5   D6  Dmed_7  Dmed_8  DMed_1  DMed_2  ...  DMed_9  \
# 0  21.0  2.0  1.0  6.0  1.0  1.0    30.0   152.0     4.0     1.0  ...     3.0
# 1  22.0  2.0  1.0  4.0  3.0  1.0    29.0   150.0     3.0     1.0  ...     3.0
# 2  33.0  2.0  1.0  6.0  6.0  1.0    32.0   160.0     1.0     1.0  ...     6.0
# 3  17.0  2.0  1.0  5.0  6.0  1.0    31.0   168.0     5.0     1.0  ...     2.0
# 4  17.0  1.0  1.0  4.0  1.0  1.0    34.0   220.0     5.0     1.0  ...     3.0
#
#    Dmed_10  Dmed_5  Dmed_6  HC_1  HC_2  HC_3  HC_4  HC_5  Rx2
# 0      5.0     1.0     1.0   5.0   5.0   5.0   5.0   4.0  4.0
# 1      6.0     1.0     1.0   5.0   5.0   5.0   5.0   5.0  3.0
# 2      5.0     1.0     1.0   4.0   4.0   4.0   4.0   4.0  4.0
# 3      5.0     1.0     3.0   4.0   4.0   5.0   4.0   3.0  3.0
# 4      4.0     7.0    15.0   5.0   5.0   5.0   5.0   3.0  2.0
#
# [5 rows x 21 columns]
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\2232870691.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = train_data[column].apply(clean_numeric)

# %% [markdown]
# ## Categorize into subgroups

# %%
data['Dmed_5'].value_counts()
# Out:
# Dmed_5
# 1.0    6330
# 7.0    1033
# 2.0     183
# 3.0     172
# 6.0     139
# 5.0     137
# 4.0     126
# Name: count, dtype: int64

# %%
# Transform numeric variables into categorical
# Age groups
bins = [1, 13, 23, 33, 43, 83] 
labels = ['18-29', '30-39', '40-49', '50-59', '60 and above']
train_data['D1'] = pd.cut(train_data['D1'], bins=bins, labels=labels, right=False)

bins = 4
train_data['Dmed_7'] = pd.cut(train_data['Dmed_7'], bins=bins, labels=False)


# Weight into categories (example bins, adjust as necessary)
bins_weight = [0, 125, 150, 175, 200, np.inf]
labels_weight = ['<125 lbs', '125-150 lbs', '150-175 lbs', '175-200 lbs', '>200 lbs']
train_data['Dmed_8'] = pd.cut(train_data['Dmed_8'], bins=bins_weight, labels=labels_weight, right=False)



#behavioral
def convert_to_categorical(df):
    # 转换处方药物数量
    df['DMed_1'] = pd.cut(df['DMed_1'], bins=[-1, 1, 3, float('inf')], labels=['1 or less', '2-3', 'More than 3'])

    # 将是否有主要护理医师的回答转为分类数据
    df['DMed_2'] = df['DMed_2'].apply(lambda x: 'Yes' if x == 1 else 'No')

    # 转换过去两年访问主要护理医师的次数
    df['DMed_3'] = pd.cut(df['DMed_3'], bins=[-1, 2, 5, float('inf')], labels=['0-2 times', '3-5 times', 'More than 5 times'])

    # 转换每周运动小时数
    df['DMed_9'] = pd.cut(df['DMed_9'], bins=[-1, 2, 5, 10, float('inf')], labels=['0-2 hours', '3-5 hours', '6-10 hours', 'More than 10 hours'])

    # 转换吸烟频率
    df['Dmed_5'] = pd.cut(df['Dmed_5'], bins=[0, 2, 4, 8], labels=['Non-smoker', 'Occasional smoker', 'Regular smoker'])

    # 转换每周饮酒量
    df['Dmed_6'] = pd.cut(df['Dmed_6'], bins=[-1, 2, 5, float('inf')], labels=['0-2 drinks', '3-5 drinks', 'More than 5 drinks'])

    # 转换健康意识相关问题
    health_statements = ['HC_1', 'HC_2', 'HC_3', 'HC_4', 'HC_5']
    for col in health_statements:
        df[f'{col}'] = pd.cut(df[col], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])

    # 转换健康总体描述
    df['Rx2'] = pd.cut(df['Rx2'], bins=[0, 2, 4, 5], labels=['Poor', 'Fair', 'Good'])

    return df


train_data = convert_to_categorical(train_data)

# %%
train_data
# Out:
#                 D1   D2   D3   D4   D5   D6  Dmed_7       Dmed_8       DMed_1  \
# 0            30-39  2.0  1.0  6.0  1.0  1.0       1  150-175 lbs  More than 3
# 1            30-39  2.0  1.0  4.0  3.0  1.0       1  150-175 lbs          2-3
# 2            50-59  2.0  1.0  6.0  6.0  1.0       2  150-175 lbs    1 or less
# 3            30-39  2.0  1.0  5.0  6.0  1.0       1  150-175 lbs  More than 3
# 4            30-39  1.0  1.0  4.0  1.0  1.0       2     >200 lbs  More than 3
# ...            ...  ...  ...  ...  ...  ...     ...          ...          ...
# 8497         50-59  2.0  2.0  5.0  3.0  1.0       1     <125 lbs    1 or less
# 8498         18-29  2.0  2.0  4.0  1.0  1.0       2     >200 lbs    1 or less
# 8499  60 and above  1.0  1.0  5.0  6.0  1.0       2     >200 lbs          2-3
# 8500         40-49  2.0  2.0  5.0  3.0  1.0       1  125-150 lbs    1 or less
# 8501         40-49  1.0  1.0  4.0  3.0  1.0       2     >200 lbs    1 or less
#
#      DMed_2  ...      DMed_9 Dmed_10             Dmed_5              Dmed_6  \
# 0       Yes  ...   3-5 hours     5.0         Non-smoker          0-2 drinks
# 1       Yes  ...   3-5 hours     6.0         Non-smoker          0-2 drinks
# 2       Yes  ...  6-10 hours     5.0         Non-smoker          0-2 drinks
# 3       Yes  ...   0-2 hours     5.0         Non-smoker          3-5 drinks
# 4       Yes  ...   3-5 hours     4.0     Regular smoker  More than 5 drinks
# ...     ...  ...         ...     ...                ...                 ...
# 8497    Yes  ...   3-5 hours     5.0         Non-smoker          0-2 drinks
# 8498    Yes  ...  6-10 hours     5.0         Non-smoker  More than 5 drinks
# 8499    Yes  ...  6-10 hours     5.0         Non-smoker          0-2 drinks
# 8500    Yes  ...   3-5 hours     4.0         Non-smoker          0-2 drinks
# 8501    Yes  ...  6-10 hours     4.0  Occasional smoker  More than 5 drinks
#
#           HC_1      HC_2     HC_3      HC_4      HC_5   Rx2
# 0        Agree     Agree    Agree     Agree   Neutral  Fair
# 1        Agree     Agree    Agree     Agree     Agree  Fair
# 2      Neutral   Neutral  Neutral   Neutral   Neutral  Fair
# 3      Neutral   Neutral    Agree   Neutral   Neutral  Fair
# 4        Agree     Agree    Agree     Agree   Neutral  Poor
# ...        ...       ...      ...       ...       ...   ...
# 8497     Agree     Agree    Agree     Agree   Neutral  Fair
# 8498     Agree     Agree    Agree     Agree     Agree  Fair
# 8499     Agree     Agree    Agree     Agree     Agree  Fair
# 8500  Disagree  Disagree    Agree  Disagree  Disagree  Fair
# 8501   Neutral   Neutral  Neutral   Neutral   Neutral  Fair
#
# [8120 rows x 21 columns]

# %%
# Ensure all features are treated as categorical
train_data = train_data.astype('category')

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from umap import UMAP
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Assuming 'train_data' is your DataFrame containing the categorical data

# One-hot encode all categorical features
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_categorical = encoder.fit_transform(train_data)
encoded_categorical_df = pd.DataFrame(encoded_categorical, columns=encoder.get_feature_names_out(train_data.columns))

# Standardize the encoded features
scaler = StandardScaler()
scaled_encoded_categorical_df = scaler.fit_transform(encoded_categorical_df)

# Apply UMAP for dimensionality reduction
umap = UMAP(n_components=3, n_neighbors=30, min_dist=0.3, random_state=42)
reduced_data = umap.fit_transform(scaled_encoded_categorical_df)

def test_k_values(reduced_data, max_k):
    silhouette_scores = []
    k_values = range(3, max_k + 1)
    for k in k_values:
        kmeans = KMeans(n_clusters=k, random_state=42)
        cluster_labels = kmeans.fit_predict(reduced_data)
        silhouette_avg = silhouette_score(reduced_data, cluster_labels)
        silhouette_scores.append(silhouette_avg)
        print(f'For n_clusters = {k}, the average silhouette score is: {silhouette_avg:.4f}')
    return k_values, silhouette_scores

# Test k values from 2 to 15
k_values, silhouette_scores = test_k_values(reduced_data, 15)

import matplotlib.pyplot as plt

# Plot silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(k_values, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters, k')
plt.ylabel('Average Silhouette Score')
plt.title('Silhouette Scores for Different Numbers of Clusters')
plt.grid(True)
plt.show()
# Out:
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# For n_clusters = 3, the average silhouette score is: 0.4002
# For n_clusters = 4, the average silhouette score is: 0.3916
# For n_clusters = 5, the average silhouette score is: 0.4042
# For n_clusters = 6, the average silhouette score is: 0.4213
# For n_clusters = 7, the average silhouette score is: 0.4317
# For n_clusters = 8, the average silhouette score is: 0.4308
# For n_clusters = 9, the average silhouette score is: 0.4345
# For n_clusters = 10, the average silhouette score is: 0.4078
# For n_clusters = 11, the average silhouette score is: 0.4110
# For n_clusters = 12, the average silhouette score is: 0.4215
# For n_clusters = 13, the average silhouette score is: 0.4316
# For n_clusters = 14, the average silhouette score is: 0.4304
# For n_clusters = 15, the average silhouette score is: 0.4373

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import OneHotEncoder
from umap import UMAP
import pandas as pd

# 假设 train_data 是你的DataFrame，包含所有要编码的类别特征
categorical_columns = train_data.columns.tolist()

# One-hot encode all categorical features
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_categorical = encoder.fit_transform(train_data[categorical_columns])
encoded_categorical_df = pd.DataFrame(encoded_categorical, columns=encoder.get_feature_names_out(categorical_columns))

# Apply UMAP for 3D dimensionality reduction
umap = UMAP(n_components=3, random_state=42)
reduced_data = umap.fit_transform(encoded_categorical_df)

# 假设 reduced_data 是已经降维处理的数据
kmeans = KMeans(n_clusters=best_k, random_state=42)
cluster_labels = kmeans.fit_predict(reduced_data)
centroids = kmeans.cluster_centers_

# 添加聚类标签到原始数据
train_data['clusters'] = cluster_labels
data['clusters'] = cluster_labels

# 计算并打印轮廓系数
silhouette_avg = silhouette_score(reduced_data, cluster_labels)
print(f'Silhouette Score for K-means with k={best_k}: {silhouette_avg:.4f}')

# 绘制3D UMAP结果、聚类标签和质心
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# 绘制数据点
sc = ax.scatter(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2], c=cluster_labels, cmap='viridis', s=5, alpha=0.5)
# 绘制质心
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], c='red', s=50, marker='x')  # 以红色'x'标记质心

ax.set_title('3D UMAP Dimensionality Reduction with K-means Clustering and Centroids')
ax.set_xlabel('UMAP Feature 1')
ax.set_ylabel('UMAP Feature 2')
ax.set_zlabel('UMAP Feature 3')
fig.colorbar(sc, label='Cluster')

plt.show()
# Out:
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Silhouette Score for K-means with k=3: 0.8242

# %%
data[train_data.columns] = train_data

# 分割数据集为7个子数据集
clustered_datasets = {}
for i in range(best_k):
    clustered_datasets[f'Cluster_{i}'] = data[data['clusters'] == i]

# 显示每个子数据集的前几行，验证分割的正确性
for cluster, dataset in clustered_datasets.items():
    print(f"Dataset for {cluster} (first 5 rows):")
    print(dataset.head())
    print("\n")
# Out:
# Dataset for Cluster_0 (first 5 rows):
#     File  Row   Q1   Q2   Q3  Q4  FQ1  FQ2  FQ3  ComQ1  ...  Dmed_7  \
# 3      1    4  5.0  5.0  4.0   4  3.0  4.0    3    1.0  ...       1
# 6      1    7  3.0  5.0  4.0   2  2.0  2.0    2    2.0  ...       1
# 10     1   11  4.0  4.0  3.0   5  3.0  1.0    3    1.0  ...       1
# 11     1   12  5.0  2.0  2.0   4  3.0  2.0    3    1.0  ...       1
# 12     1   13  5.0  5.0  5.0   5  3.0  4.0    3    1.0  ...       1
#
#          Dmed_8       DMed_1 DMed_2             DMed_3      DMed_9  Dmed_10  \
# 3   150-175 lbs  More than 3    Yes  More than 5 times   0-2 hours      5.0
# 6   125-150 lbs          2-3     No          3-5 times   3-5 hours      2.0
# 10  150-175 lbs          2-3    Yes          3-5 times   3-5 hours      5.0
# 11     <125 lbs          2-3    Yes  More than 5 times  6-10 hours      5.0
# 12  125-150 lbs          2-3    Yes          3-5 times  6-10 hours      4.0
#
#                Dmed_5      Dmed_6  clusters
# 3          Non-smoker  3-5 drinks         0
# 6          Non-smoker  0-2 drinks         0
# 10  Occasional smoker  3-5 drinks         0
# 11     Regular smoker  0-2 drinks         0
# 12         Non-smoker  0-2 drinks         0
#
# [5 rows x 124 columns]
#
#
# Dataset for Cluster_1 (first 5 rows):
#    File  Row   Q1   Q2   Q3  Q4  FQ1  FQ2  FQ3  ComQ1  ...  Dmed_7  \
# 2     1    3  5.0  5.0  4.0   4  3.0  1.0    3    1.0  ...       2
# 4     1    5  5.0  5.0  5.0   5  3.0  1.0    3    1.0  ...       2
# 5     1    6  5.0  5.0  5.0   4  3.0  1.0    3    1.0  ...       2
# 8     1    9  5.0  5.0  5.0   4  3.0  2.0    3    2.0  ...       2
# 9     1   10  5.0  5.0  5.0   4  3.0  1.0    3    1.0  ...       2
#
#         Dmed_8       DMed_1 DMed_2             DMed_3      DMed_9  Dmed_10  \
# 2  150-175 lbs    1 or less    Yes          3-5 times  6-10 hours      5.0
# 4     >200 lbs  More than 3    Yes  More than 5 times   3-5 hours      4.0
# 5  175-200 lbs    1 or less    Yes          0-2 times   0-2 hours      1.0
# 8  125-150 lbs    1 or less    Yes          3-5 times   0-2 hours      4.0
# 9  175-200 lbs    1 or less     No          0-2 times   0-2 hours      6.0
#
#            Dmed_5              Dmed_6  clusters
# 2      Non-smoker          0-2 drinks         1
# 4  Regular smoker  More than 5 drinks         1
# 5  Regular smoker  More than 5 drinks         1
# 8      Non-smoker          0-2 drinks         1
# 9      Non-smoker  More than 5 drinks         1
#
# [5 rows x 124 columns]
#
#
# Dataset for Cluster_2 (first 5 rows):
#     File  Row   Q1   Q2   Q3  Q4  FQ1  FQ2  FQ3  ComQ1  ...  Dmed_7  \
# 0      1    1  5.0  5.0  4.0   5  3.0  1.0    3    1.0  ...       1
# 1      1    2  4.0  4.0  4.0   4  3.0  1.0    3    2.0  ...       1
# 7      1    8  3.0  4.0  4.0   4  3.0  2.0    3    2.0  ...       1
# 13     1   14  5.0  5.0  5.0   4  3.0  1.0    3    1.0  ...       1
# 22     1   23  5.0  5.0  5.0   5  3.0  2.0    3    1.0  ...       1
#
#          Dmed_8       DMed_1 DMed_2             DMed_3      DMed_9  Dmed_10  \
# 0   150-175 lbs  More than 3    Yes          3-5 times   3-5 hours      5.0
# 1   150-175 lbs          2-3    Yes  More than 5 times   3-5 hours      6.0
# 7   125-150 lbs    1 or less    Yes          3-5 times   3-5 hours      5.0
# 13     <125 lbs  More than 3    Yes  More than 5 times   0-2 hours      5.0
# 22  125-150 lbs    1 or less     No          0-2 times  6-10 hours      6.0
#
#         Dmed_5      Dmed_6  clusters
# 0   Non-smoker  0-2 drinks         2
# 1   Non-smoker  0-2 drinks         2
# 7   Non-smoker  0-2 drinks         2
# 13  Non-smoker  0-2 drinks         2
# 22  Non-smoker  0-2 drinks         2
#
# [5 rows x 124 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 绘制条形图
sns.countplot(x='clusters', data=data)
plt.title('Distribution of Clusters')
plt.xlabel('Cluster')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Significance Testing

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 定义映射字典
sex_map = {1: 'Male', 2: 'Female'}
race_map = {
    1: 'White', 2: 'Black or African American', 3: 'Asian', 
    4: 'Native American or American Indian', 5: 'Native Hawaiian or Pacific Islander', 
    6: 'Multiracial or biracial', 7: 'Other', 8: 'I choose not to answer'
}
education_map = {
    1: '8th grade or less', 2: 'Attended high school', 3: 'High school graduate',
    4: 'Some college', 5: 'College graduate', 6: 'Some graduate school',
    7: 'Grad / professional degree', 8: 'I choose not to answer'
}
income_map = {
    1: 'Less than $20,000', 2: '$20,000 - $34,999', 3: '$35,000 - $54,999',
    4: '$55,000 - $74,999', 5: '$75,000 - $89,999', 6: '$90,000 or more',
    7: 'Do not know / not sure', 8: 'I choose not to answer'
}
english_first_language_map = {0: 'No', 1: 'Yes'}



# 创建原数据的副本
mapped_data = train_data.copy()

# 应用映射到副本数据
mapped_data['D2'] = mapped_data['D2'].map(sex_map)
mapped_data['D3'] = mapped_data['D3'].map(race_map)
mapped_data['D4'] = mapped_data['D4'].map(education_map)
mapped_data['D5'] = mapped_data['D5'].map(income_map)
mapped_data['D6'] = mapped_data['D6'].map(english_first_language_map)

# 提取特征和群集标签
demographic_features = mapped_data.columns.tolist()
clusters = mapped_data['clusters']

# 计算每个群集中类别特征的众数（模式）
categorical_centroids = mapped_data.groupby(clusters).agg(lambda x: x.mode()[0])

# 显示众数表
print(categorical_centroids)

# 可视化每个类别特征在不同群集中的众数比例
for feature in demographic_features:
    if feature == 'clusters':
        continue
    mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
    mode_counts = mode_counts.div(mode_counts.sum(axis=1), axis=0)  # 归一化以进行百分比比较

    mode_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
    plt.title(f'Mode Comparison of {feature} Across Clusters')
    plt.xlabel('Clusters')
    plt.ylabel('Proportion')
    plt.legend(title=feature, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()
# Out:
#                     D1      D2     D3                D4                 D5  \
# clusters
# 0                18-29  Female  White  College graduate  $20,000 - $34,999
# 1                30-39    Male  White  College graduate  $35,000 - $54,999
# 2         60 and above  Female  White  College graduate  $35,000 - $54,999
#
#            D6 Dmed_7       Dmed_8     DMed_1 DMed_2  ...     DMed_9 Dmed_10  \
# clusters                                             ...
# 0         Yes      1  125-150 lbs  1 or less    Yes  ...  0-2 hours     4.0
# 1         Yes      2     >200 lbs  1 or less    Yes  ...  3-5 hours     5.0
# 2         Yes      1  125-150 lbs  1 or less    Yes  ...  3-5 hours     5.0
#
#               Dmed_5      Dmed_6     HC_1     HC_2     HC_3     HC_4     HC_5  \
# clusters
# 0         Non-smoker  0-2 drinks  Neutral  Neutral  Neutral  Neutral  Neutral
# 1         Non-smoker  0-2 drinks  Neutral  Neutral  Neutral  Neutral  Neutral
# 2         Non-smoker  0-2 drinks    Agree    Agree    Agree    Agree    Agree
#
#            Rx2
# clusters
# 0         Fair
# 1         Fair
# 2         Fair
#
# [3 rows x 21 columns]
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)
# C:\Users\howar\AppData\Local\Temp\ipykernel_24176\609885290.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_counts = mapped_data.groupby(['clusters', feature]).size().unstack(fill_value=0)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import pairwise_distances_argmin_min

# 假设 reduced_data 是UMAP降维后的数据，original_data 是原始数据
# kmeans 是已经在降维数据上训练好的 KMeans 模型
closest, _ = pairwise_distances_argmin_min(kmeans.cluster_centers_, reduced_data)

# 假设 original_data 是一个 DataFrame，包含聚类之前的全部原始数据
original_centroids = demographic_data.iloc[closest]

original_centroids['D2'] = original_centroids['D2'].map(sex_map)
original_centroids['D3'] = original_centroids['D3'].map(race_map)
original_centroids['D4'] = original_centroids['D4'].map(education_map)
original_centroids['D5'] = original_centroids['D5'].map(income_map)
original_centroids['D6'] = original_centroids['D6'].map(english_first_language_map)

print("Original data points closest to centroids:")
print(original_centroids)
# Out:
# Original data points closest to centroids:
#         D1      D2                         D3                    D4  \
# 6157  59.0  Female                      White  High school graduate
# 7430  12.0  Female                      White      College graduate
# 1882  38.0    Male  Black or African American          Some college
#
#                           D5   D6  Dmed_7 Dmed_8  clusters
# 6157       $35,000 - $54,999  Yes    26.0    185         6
# 7430       Less than $20,000  Yes    32.0    115         1
# 1882  I choose not to answer  Yes    37.0    165         5
# C:\Users\howar\AppData\Local\Temp\ipykernel_16344\3038673244.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original_centroids['D2'] = original_centroids['D2'].map(sex_map)
# C:\Users\howar\AppData\Local\Temp\ipykernel_16344\3038673244.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original_centroids['D3'] = original_centroids['D3'].map(race_map)
# C:\Users\howar\AppData\Local\Temp\ipykernel_16344\3038673244.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original_centroids['D4'] = original_centroids['D4'].map(education_map)
# C:\Users\howar\AppData\Local\Temp\ipykernel_16344\3038673244.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original_centroids['D5'] = original_centroids['D5'].map(income_map)
# C:\Users\howar\AppData\Local\Temp\ipykernel_16344\3038673244.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original_centroids['D6'] = original_centroids['D6'].map(english_first_language_map)

# %% [markdown]
# ## 2. Pretrain GPT Model

# %% [markdown]
# ### GPT4

# %%
# 假设 data 是你的Pandas DataFrame
output_dir_train = 'Data\clusters\demographic_and_behavioral/train'
output_dir_test = 'Data\clusters\demographic_and_behavioral/test'

if not os.path.exists(output_dir_train):
    os.makedirs(output_dir_train)

if not os.path.exists(output_dir_test):
    os.makedirs(output_dir_test)

# %%
#condition?
def convert_to_prompt_demo(row):
    # Age
    age = f"{row['D1']} years old" if not pd.isna(row['D1']) else "unknown age"
    
    # Sex
    sex = "male" if row['D2'] == 1 else "female" if row['D2'] == 2 else "unknown sex"
    
    # Race
    race_options = [
        "White", "Black or African American", "Asian", 
        "Native American or American Indian", "Native Hawaiian or Pacific Islander", 
        "Multiracial or biracial", "Other", "Prefer not to say"
    ]
    race = race_options[int(row['D3']) - 1] if not pd.isna(row['D3']) else "unknown race"
    
    # Education
    education_options = [
        "8th grade or less", "some high school education", "high school graduate", 
        "some college education", "college graduate", "some graduate school education", 
        "a graduate or professional degree", "prefer not to say"
    ]
    education = education_options[int(row['D4']) - 1] if not pd.isna(row['D4']) else "unknown educational background"
    
    # Income
    income_options = [
        "less than $20,000", "$20,000 - $34,999", "$35,000 - $54,999", 
        "$55,000 - $74,999", "$75,000 - $89,999", "$90,000 or more", 
        "unknown income", "prefer not to say"
    ]
    income = income_options[int(row['D5']) - 1] if not pd.isna(row['D5']) else "unknown income"
    
    # Language
    english_first_lang = "English is your first language" if row['D6'] == 1 else \
                         "English is not your first language" if row['D6'] == 2 else \
                         "it is unknown if English is your first language"
    
    # Physical measurements
    height = f"{row['Dmed_7']} feet tall" if not pd.isna(row['Dmed_7']) else "unknown height"
    weight = f"weighs {row['Dmed_8']} pounds" if not pd.isna(row['Dmed_8']) else "unknown weight"
    
    # Combine all into one prompt
    prompt = (
        f"You are {age}, {sex}, of {race} descent. You have {education} and an annual income of {income}. "
        f"{english_first_lang}. You are {height} and {weight}."
    )
    
    return prompt


def convert_to_prompt_behavioral(row):
    intro = "You are someone who "

    # 根据药物数量
    if row['DMed_1'] == '1 or less':
        intro += "takes few or no prescription drugs regularly, "
    elif row['DMed_1'] == '2-3':
        intro += "takes a moderate number of prescription drugs regularly, "
    else:
        intro += "takes many prescription drugs regularly, "

    # 根据是否有主要护理医师
    if row['DMed_2'] == 'Yes':
        intro += "has a primary care physician, "
    else:
        intro += "does not have a primary care physician, "

    # 根据访问医师的频率
    if row['DMed_3'] == '0-2 times':
        intro += "and rarely visits them. "
    elif row['DMed_3'] == '3-5 times':
        intro += "and occasionally visits them. "
    else:
        intro += "and frequently visits them. "

    # 根据运动小时数
    if row['DMed_9'] == '0-2 hours':
        intro += "You engage in little physical activity weekly. "
    elif row['DMed_9'] == '3-5 hours':
        intro += "You have a moderate weekly physical activity. "
    elif row['DMed_9'] == '6-10 hours':
        intro += "You are quite active physically on a weekly basis. "
    else:
        intro += "You are very active, engaging in many hours of physical activity every week. "

    # 结合健康意识
    if row['HC_1'] == 'Agree':
        intro += "Living in the best possible health is very important to you. "

    return intro

# %%
# 分割数据集为7个子数据集并进行训练/测试分割
clustered_datasets = {}
train_datasets = {}
test_datasets = {}

for i in range(best_k):  
    cluster_data = data[data['clusters'] == i].head(100)
    train, test = train_test_split(cluster_data, test_size=0.2, random_state=42)  # 20% 数据作为测试集
    train_datasets[f'Cluster_{i}'] = train
    test_datasets[f'Cluster_{i}'] = test


def convert_to_jsonl_format(clustered_datasets, output_dir):
    for cluster, dataset in clustered_datasets.items():
        # Fill missing values
        
        jsonl_data = []
        for index, row in dataset.iterrows():
            system_prompt = "You should simulate a specified person's persona based on the background information I provided. You are currently visiting a psychologist." + convert_to_prompt_demo(row) + convert_to_prompt_behavioral(row)
            # Combining the responses into the completion field
            jsonl_data.append({
                "messages": [
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": Text_SubjectiveLit},
                    {"role": "assistant", "content": row['Text_SubjectiveLit']},
                    {"role": "user", "content": Text_TrustPhys},
                    {"role": "assistant", "content": row['Text_TrustPhys']},
                    {"role": "user", "content": Text_Anxiety},
                    {"role": "assistant", "content": row['Text_Anxiety']},
                    {"role": "user", "content": Text_Numeracy},
                    {"role": "assistant", "content": row['Text_Numeracy']}
                ]
                })
                
        # Saving the jsonl files
        filename = os.path.join(output_dir, f"{cluster}.jsonl")
        with open(filename, 'w') as f:
            for entry in jsonl_data:
                f.write(json.dumps(entry) + "\n")
        print(f"Saved {filename}")


# 转换训练数据和测试数据为JSON格式并保存
convert_to_jsonl_format(train_datasets, output_dir_train)
convert_to_jsonl_format(test_datasets, output_dir_test)
# Out:
# Saved Data\clusters\demographic_and_behavioral/train\Cluster_0.jsonl
# Saved Data\clusters\demographic_and_behavioral/train\Cluster_1.jsonl
# Saved Data\clusters\demographic_and_behavioral/train\Cluster_2.jsonl
# Saved Data\clusters\demographic_and_behavioral/test\Cluster_0.jsonl
# Saved Data\clusters\demographic_and_behavioral/test\Cluster_1.jsonl
# Saved Data\clusters\demographic_and_behavioral/test\Cluster_2.jsonl

# %%
#modify
data_path = "Data\clusters\demographic_and_behavioral/train\Cluster_1.jsonl"

# Load the dataset
with open(data_path, 'r', encoding='utf-8') as f:
    dataset = [json.loads(line) for line in f]

# Initial dataset stats
print("Num examples:", len(dataset))
print("First example:")
for message in dataset[0]["messages"]:
    print(message)
# Out:
# Num examples: 80
# First example:
# {'role': 'system', 'content': 'You should simulate a specified person\'s persona based on the background information I provided. You are currently visiting a psychologist.You are 30-39 years old, male, of White descent. You have high school graduate and an annual income of $20,000 - $34,999. English is your first language. You are <5\'4" feet tall and weighs 150-175 lbs pounds.You are someone who takes few or no prescription drugs regularly, has a primary care physician, and occasionally visits them. You engage in little physical activity weekly. '}
# {'role': 'user', 'content': 'Regarding all the questions you just answered, to what degree do you feel you have the capacity to obtain, process, and understand basic health information and services needed to make appropriate health decisions? Please explain your answer in a few sentences.'}
# {'role': 'assistant', 'content': 'I feel I have a pretty good grasp on understanding the various aspects of healthcare. I make sure to read materials thoroughly and, like with contracts, I always make sure to read fine print and ask questions about things I do not understand. The internet allows me to do basic research on things I might need to ask or clarify. I trust my doctors to provide me with the proper information and I trust them to explain things to me in terms that I can understand.'}
# {'role': 'user', 'content': 'In a few sentences, please explain the reasons why you trust or distrust your primary care physician. If you do not have a primary care physician, please answer in regard to doctors in general.'}
# {'role': 'assistant', 'content': 'My doctor has little reason to lie to me, so I can trust in them to provide me with the proper care. I do question medications when I can, as I know that doctors receive kickbacks and things like that from companies. I try to make sure to use holistic methods when I can. Medications can be dangerous and harmful if you become addicted to them. I prefer to use natural methods when I can, so that I can avoid anything unnecessary.'}
# {'role': 'user', 'content': "In a few sentences, please describe what makes you feel most anxious or worried when visiting the doctor's office."}
# {'role': 'assistant', 'content': "Just being there is sometimes unsettling. It is hard to keep bad thoughts out when you are surrounded by sick people and the smell of a doctor's office. However, I know that my health is separate from others, so I try to keep the bad thoughts out by focusing on myself first. I get a little uneasy when waiting for test results or after an exam, but I know that I can get over it quickly."}
# {'role': 'user', 'content': 'In a few sentences, please describe an experience in your life that demonstrated your knowledge of health or medical issues.'}
# {'role': 'assistant', 'content': 'I have been sick before and gone to the doctor because I felt that something was different. I noticed my symptoms were slightly different from previous sickness and because of that I decided that seeing a doctor was a good idea. It turned out to be nothing, but I try to be careful when something is different from previous experiences.'}

# %%
# Format error checks
format_errors = defaultdict(int)

for ex in dataset:
    if not isinstance(ex, dict):
        format_errors["data_type"] += 1
        continue
        
    messages = ex.get("messages", None)
    if not messages:
        format_errors["missing_messages_list"] += 1
        continue
        
    for message in messages:
        if "role" not in message or "content" not in message:
            format_errors["message_missing_key"] += 1
        
        if any(k not in ("role", "content", "name", "function_call", "weight") for k in message):
            format_errors["message_unrecognized_key"] += 1
        
        if message.get("role", None) not in ("system", "user", "assistant", "function"):
            format_errors["unrecognized_role"] += 1
            
        content = message.get("content", None)
        function_call = message.get("function_call", None)
        
        if (not content and not function_call) or not isinstance(content, str):
            format_errors["missing_content"] += 1
    
    if not any(message.get("role", None) == "assistant" for message in messages):
        format_errors["example_missing_assistant_message"] += 1

if format_errors:
    print("Found errors:")
    for k, v in format_errors.items():
        print(f"{k}: {v}")
else:
    print("No errors found")
# Out:
# No errors found

# %% [markdown]
# ## 4. Testing results

# %%
models = ["ft:gpt-3.5-turbo-0125:personal:demo-beha-0:9l3EDB0v",
          "ft:gpt-3.5-turbo-0125:personal:demo-beha-1:9l3Gtr8M",
            "ft:gpt-3.5-turbo-0125:personal:demo-beha-2:9l3Elf7J",
            "gpt-3.5-turbo-0125"
            ]

user_prompt = {"Text_Numeracy": Text_Numeracy, 
               "Text_Anxiety": Text_Anxiety, 
               "Text_TrustPhys": Text_TrustPhys, 
               "Text_SubjectiveLit": Text_SubjectiveLit}

# %%
from openai import OpenAI
import json
from collections import defaultdict

client = OpenAI()

#response from a single person (i = which model, j = resp from jth question)
def perfromace_across_models(models, system_prompt, user_prompt):
  response_list = defaultdict(lambda: {prompt: [] for prompt in user_prompt})
  for i, model in enumerate(models):
    for j in user_prompt:
      response = client.chat.completions.create(
        model= model,
        messages=[{"role": "system", "content": system_prompt}, 
                  {"role": "user", "content": user_prompt[j]}],
        temperature=1,
        max_tokens=256,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
      ).choices[0].message.content
      response_list[i][j].append(response)
  
  return response_list


def dict_to_regular(d):
    if isinstance(d, defaultdict):
        d = {k: dict_to_regular(v) for k, v in d.items()}
    return d

# %%
# Path to the uploaded file
file_paths = [f'Data\clusters\demographic_and_behavioral/test\Cluster_{i}.jsonl' for i in range(best_k)]

# Reading the JSONL file and converting it to a list of dictionaries
datas = []

for file_path in file_paths:
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(json.loads(line))
    datas.append(data)

# %%
#j = jth cluster
for j, data in enumerate(datas):
    all_responses = []
    all_labels = []

    for i in range(len(data)):
        labels =  {prompt: "" for prompt in user_prompt}
        system_prompt = data[i]["messages"][0]["content"] #peronal information
        q1 = data[i]["messages"][2]["content"]  #answer for q1
        q2 = data[i]["messages"][4]["content"]
        q3 = data[i]["messages"][6]["content"]
        q4 = data[i]["messages"][8]["content"]

        user_response = perfromace_across_models(models, system_prompt, user_prompt)
        #user_response[i][j] = ith model's jth question's  response 
        labels['Text_Numeracy'] = q1
        labels['Text_Anxiety'] = q2
        labels['Text_TrustPhys'] = q3
        labels['Text_SubjectiveLit'] = q4
        
        all_responses.append(user_response)
        all_labels.append(labels)

    all_responses_output_dir = f"results/cluster_{j}/all_responses_demo_beha.json"
    all_labels_output_dir = f"results/cluster_{j}/all_labels_demo_beha.json"

    os.makedirs(os.path.dirname(all_responses_output_dir), exist_ok=True)
    os.makedirs(os.path.dirname(all_labels_output_dir), exist_ok=True)

    # 将 all_responses 中的 defaultdict 转换为普通字典
    all_responses_regular = [dict_to_regular(d) for d in all_responses]

    # 序列化为 JSON 并保存到文件
    with open(all_responses_output_dir, 'w') as f:
        json.dump(all_responses_regular, f)

    with open(all_labels_output_dir, 'w') as f:
        json.dump(all_labels, f)

# %% [markdown]
# ## Evaluation methods

# %%
all_responses = []
all_labels = []

#all_response[clust][i][j][k] = [nth clust][ith person][jth model][kth question]
#all_labels[clust][i][k] = [nth clust][ith person][kth question]

# 从文件中读取并反序列化 JSON 的函数
def regular_to_defaultdict(d):
    if isinstance(d, dict):
        return defaultdict(lambda: {prompt: [] for prompt in user_prompt},
                           {k: regular_to_defaultdict(v) for k, v in d.items()})
    return d

for i in range(best_k):
    # 从文件中读取 JSON 数据并转换回 defaultdict
    with open(f'results/cluster_{i}/all_responses_demo_beha.json', 'r') as f:
        all_responses_loaded = json.load(f)

    with open(f'results/cluster_{i}/all_labels_demo_demo_beha.json', 'r') as f:
        all_labels_loaded = json.load(f)

    all_responses.append([regular_to_defaultdict(d) for d in all_responses_loaded])
    all_labels.append([d for d in all_labels_loaded])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 16
#      12     return d
#      14 for i in range(best_k):
#      15     # 从文件中读取 JSON 数据并转换回 defaultdict
# ---> 16     with open(f'results/cluster_{i}/all_responses_demo_beha.json', 'r') as f:
#      17         all_responses_loaded = json.load(f)
#      19     with open(f'results/cluster_{i}/all_labels_demo_demo_beha.json', 'r') as f:
#
# File c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/cluster_0/all_responses_demo_beha.json'

# %% [markdown]
# ### 1. Text Similarity

# %%
from transformers import BertModel, BertTokenizer
import torch
from sklearn.metrics.pairwise import cosine_similarity

def calculate_similarity(paragraph1, paragraph2):
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = BertModel.from_pretrained('bert-base-uncased')

    # Tokenize and prepare the inputs
    inputs1 = tokenizer(paragraph1, return_tensors='pt', padding=True, truncation=True, max_length=512)
    inputs2 = tokenizer(paragraph2, return_tensors='pt', padding=True, truncation=True, max_length=512)

    # Encode the paragraphs using the BERT model
    with torch.no_grad():
        outputs1 = model(**inputs1)
        outputs2 = model(**inputs2)

    # Use mean pooling to get sentence embeddings
    embeddings1 = outputs1.last_hidden_state.mean(dim=1).numpy()
    embeddings2 = outputs2.last_hidden_state.mean(dim=1).numpy()

    # Calculate cosine similarity
    similarity = cosine_similarity(embeddings1, embeddings2)
    return similarity


all_similarities_cosine = {f"cluster_{j}" : [] for j in range(best_k)}

for clust in range(len(all_labels)):
    similarities = []
    for i, person in enumerate(all_labels[clust]):
        label = [person["Text_Numeracy"], person["Text_Anxiety"], person["Text_TrustPhys"], person["Text_SubjectiveLit"]]
        
        answer_models = [
            [all_responses[clust][i][str(model_idx)]["Text_Numeracy"],
             all_responses[clust][i][str(model_idx)]["Text_Anxiety"],
             all_responses[clust][i][str(model_idx)]["Text_TrustPhys"],
             all_responses[clust][i][str(model_idx)]["Text_SubjectiveLit"]]
            for model_idx in range(len(models))
        ]

        scores = [[] for _ in range(len(models))]  # 存放5个模型的分数

        for j in range(len(label)):
            for model_idx in range(len(models)):
                scores[model_idx].append(calculate_similarity(label[j], answer_models[model_idx][j]))

        similarities.append(scores)  # 包含所有模型的分数
    all_similarities_cosine[f"cluster_{clust}"] = similarities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27
#      23     similarity = cosine_similarity(embeddings1, embeddings2)
#      24     return similarity
# ---> 27 all_similarities_cosine = {f"cluster_{j}" : [] for j in range(best_k)}
#      29 for clust in range(len(all_labels)):
#      30     similarities = []
#
# NameError: name 'best_k' is not defined

# %%
all_responses
# Out:
# [[defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["I remember one day when i was running relays at my high school , I was in such a hurry because I won two races already and I wanted to win the 3rd one also , I literally had no time to stop and eat a full meal so I just drank water and snacked on chips all day..by the time the race came all right before the race started all i had was a chocolate milk and an apple I told my coach that I wasn't feeling well and he just brushed me off and said I was just scared..so I got ready for the race feeling like I could barely keep my eyes open and I still went out there and ran in the middle of the race I got this knot in my chest and it was hard to swallow and i started dry heaving , I was still determined to finish the race so i did but then my mom came to see me after the race and at first i was not worried at all I wanted to see my mom when i just seen her yesterday she asked me if i was okay i said no ..there was this guy there who she shouted over to call the nurse I was starting to get dizzy and I took off my shoes and asked her is their something on my chest and she told me that my chest was hard"],
#                             'Text_Anxiety': ['I am mostly uncomfortable about invasions or my personal space, However also eager to receive any negative feedback in an effort to please. Mostly concerned about discrepancies between desired and actual lifestyle. Otherwise in good shape ~ I like animals ~ Sense of humor ~ActionCreators Roleplay(Page) ~ Spells at FAE ~ACTIVEirebase'],
#                             'Text_TrustPhys': ['Well, my psychiatrist and doctors have not given me good advice in the past.  Doctors have acted unprofessional with me or made me feel uncomfortable.  Some of the pills they give me make me feel even worse.  Sometimes they lie to me about how good the pills are for me.  Also, for my physical problems and even brain problems none of the doctors I visited were well educated in the natural ways to cure what I have.'],
#                             'Text_SubjectiveLit': ['Yes I believe I have the intelligence and know how to run my good enough to in sure my wellness is on track ']}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['One particular instance in my life where I had to know some health/medical issues was when my little grandmother had to have a skin tag removed from her back; and I know it about skin tags and cancer.  But any way I hope that this information has been helpful.'],
#                             'Text_Anxiety': ['I am usually an easy going person ,but going in for an appointment is always something I a little nervous for because of that one appointment I went in happy for and came out crying '],
#                             'Text_TrustPhys': ['I trust them, because they have alot of schooling behind them and they seem like they know what they\'re talking about. They present me with options in my care and we discuss them together. If I don\'t feel comfortable with their suggestion then I present that to them and we come to a better option together. I distrust hospitals and the "bigger picture". If i don\'t come with a health problem then I tend to leave with one and suggest we treat it \'preventivley\'.'],
#                             'Text_SubjectiveLit': ["I can't remember what I answered for this question.  I think about 5 or 10 years ago standaredized test makers would have call this question reading comprehension but it didn't secure the partisipation of the English as a second language  crowd so they started calling  it heathy literacy.  With the right healthy literacy of above a six grade level cst reaserch tells us that teenagers are more than half the ones that die from injuries violence and other things that kill  to high percentages supreme court justices.  Some research in tbe nebraska prisons indicates those that struggle with heathy literacy often struggle with the law in relation to mental health and regional intelligence.  Some apartt of the brain the  self monitoring part the executive function part if you will appers also to be tied to health literacy level in adults.  People assure me however that this ism't genetic they reasure in no intelligence is so it must be fixed by a greade fix The reaserch back story however reminds us that unlike test scores their was an actual untamed neandethol brain which actually would have caused its owner to have low regional intelligence.  Advances of learning to teach to all learning styles as well as fitness to electricity improved the level of regional"]}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["Due to the fact that my Dad has high blood pressure I am very much aware of the health issues that he must deal with. I've seen firsthand the importance of maintaining a healthy lifestyle including regular doctor visits, good diet and exercise. "],
#                             'Text_Anxiety': ['I think I am most afraid when a doctor finds something wrong with my health. For example, nothing bad ever shows up on my urine strips at the gynecologist office. I would be terrified if something abnormal showed up one day.'],
#                             'Text_TrustPhys': ['I trust my primary care physician because I feel that they are well educated and experienced. I also trust them because they have helped me in the past and I respect what they have done for me. '],
#                             'Text_SubjectiveLit': ["I'm decently versed on health issues, I am a moderate consumer of health reports (vague health effects reports etc).  Also, I have come in contact with numerous health providers as well, therefore I can articulate broadly on manager such issues"]}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I remember a few years ago when my younger sister was diagnosed with asthma. I took it upon myself to research extensively about asthma, its symptoms, triggers, and management techniques. I accompanied her to doctor appointments, asked relevant questions, and made sure she understood her medication and treatment plan. I also helped create a clean and dust-free environment at home to minimize her asthma attacks. It was a challenging time, but being educated about her condition helped me support her better.'],
#                             'Text_Anxiety': ["I often feel anxious when visiting the doctor's office due to a fear of receiving bad news about my health. I worry about potential health issues that may be discovered during the visit and the implications they may have on my daily life and future. Additionally, I feel uneasy about discussing personal health matters with someone I may not know well or feel comfortable with."],
#                             'Text_TrustPhys': ['I trust my primary care physician because they have always listened to my concerns attentively, taken the time to explain things to me in a way I understand, and shown genuine care for my well-being. They have consistently provided me with thorough and accurate information about my health and treatment options. I feel comfortable discussing any health issue with them and believe they have my best interests at heart.'],
#                             'Text_SubjectiveLit': ['I believe I have a moderate level of capacity to obtain, process, and understand basic health information and services. While I do have a primary care physician whom I visit regularly and I am aware of the importance of maintaining my health, I may not always fully comprehend all the medical jargon or complex health issues that are discussed during my appointments. I try to stay informed by asking questions and researching information, but I do acknowledge that there is always room for improvement in my health literacy.']})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I have a heart condition (arrhythmia) that required cardiac ablation two years ago. I have also had a stroke.'],
#                             'Text_Anxiety': ['I get anxious when I do not know what to expect.  I am embarrassed about my weight and knowing I will have to get on the scales is frightening to me.'],
#                             'Text_TrustPhys': ['I only go to my primary care physician for my entire medical needs.  have great respect for her. She is very caring and helpful.  She goes out of her way to make me comfortable.'],
#                             'Text_SubjectiveLit': ["I have zero medical training, and my doctor ends up needing to explain part of it every time I go in. I'm not sure where to go for additional resources, or if I even know what questions to ask."]}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I could not recall any special event that reminded me that I need better medical assistant. '],
#                             'Text_Anxiety': ["I'm always afraid they'll find something wrong with me, when I feel better than ever.  And I don't have the money to pay for medical bills. "],
#                             'Text_TrustPhys': ["I dislike going to the doctor's, and always afraid that they will tell me that I am getting ready to die.  I take anti depressant medication and some doctors and doctors assistant always have something negative to say about that and I hate their attitude towards this.  Also they want me to take unsolicited tests all the  time and these tests can cost me money that I do my have and is not anything that has hurt me physically."],
#                             'Text_SubjectiveLit': ['I do not trust myself to understand all of the information.']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["When my husband was sick for two weeks but refused to go see the doctor, I demanded that we go to the ER, even though he was dragging his feet. I was concerned that he had bronchial pneumonia, because his primary care doctor wasn't dealing with this as aggressively as I wanted. We turned out to be right -- he had community-acquired pneumonia and spent the night in the ER. "],
#                             'Text_Anxiety': ['I get anxiety when I hear the word cancer or when a doctor tells me they have found something out abnorma'],
#                             'Text_TrustPhys': ['I trust most doctors, they know more than I do. I would like to be better informed about my care. '],
#                             'Text_SubjectiveLit': ['I don’t have any trouble understanding anything that I have read or doctors have said to me with my current health_CONDITION_BehaviorMENTS. I feel that if and when I don’t understand something explained to me., as a rule I ask my doctor what that means.']}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I remember back when my husband was diagnosed with diabetes many years ago. I took on the responsibility of learning all about the disease, including how to manage his medication, monitor his blood sugar levels, and prepare appropriate meals for him. I attended numerous doctor appointments with him and made sure he followed his treatment plan diligently. It was a challenging time, but I was dedicated to supporting him and ensuring he stayed as healthy as possible.'],
#                             'Text_Anxiety': ["I always feel anxious when visiting the doctor's office because I worry about my health conditions and the possibility of receiving bad news regarding my medications or overall well-being. I also get nervous about discussing my symptoms and concerns with the healthcare providers, as I fear being judged for my weight and lifestyle choices. Additionally, I often feel overwhelmed by the medical jargon and information that is shared during the appointments."],
#                             'Text_TrustPhys': ['I trust my primary care physician because they have been taking care of me for many years and have always been attentive to my health concerns. I appreciate that they take the time to explain things to me in a way that I can understand and always listen to my questions and address any doubts I may have. Additionally, they have helped me manage my various health conditions effectively through medication and regular check-ups.'],
#                             'Text_SubjectiveLit': ["Well, I think I struggle a bit with understanding all the medical information sometimes. There are just so many new medications and treatments out there, it can be overwhelming. I do my best to listen to my doctor and ask questions when I don't understand, but it can still be confusing. I rely a lot on my primary care physician to help guide me through everything."]})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['Durning my previous job at a caregiving facilty, I have shown my knowledge of medical by helping a stroke patient get from sitting to couch. I also helped residents with medicinal dosages. As well as provenly  by practice cpr to get my cpr certification.'],
#                             'Text_Anxiety': ["I'm transexual and not sure if the doctor monologue  about my dick and how I  using it  just be polite or is he /she really interesting in learning about the past surgery .I  going to paste the surgery letter in  hehlps to refer him instead of  same thing over and over on my part\tthen add the med list him/her  for emergency use in case of  911 call \tprocess. "],
#                             'Text_TrustPhys': ["Well, I have a lot of trust in my doctor, he's usually quick to answer my questions and takes the time to explain to me any concerns I might have. He loves to help me as best he can, and always generally makes me feel safe. I can tell he genuinely cares when he's working with me. there are some issues that i have trust issues mostly due to the fact that he sometimes gives me attitude when I want to know more about procedures and so forth. Other than that, he's a great doctor who discloses only what really needs to be disclosed."],
#                             'Text_SubjectiveLit': ['I believe I do have the capacity to obtain, process, and understand basic health information. I am also intelligent enough to recognize ignorance of any health information. My challenge comes in my inability to self-motivate myself to get to a professional health care provider for any open questions I may have.']}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I have a condition that requires surgical intervention and as a college student I handled all the arrangements on my own. '],
#                             'Text_Anxiety': ['I am always worried about them telling me something is wrong with me.  3 years ago something was wrong with my utorous and i had to have it removed.  Now the doctor said he wants to keep a eye on me.  '],
#                             'Text_TrustPhys': ["I don't actually have one so this is about doctors in general. My mom's doctor was her OB/GYN and I remember her having her sign papers saying she'd get her tubes tied after giving birth to her 3rd kid and lying about just smoking. He shouldn't have pushed her into that. He shouldn't have lied. He should have listened to her welfare, not his health of her reproductive system. Smokig and having an extra kid would have been better for her mental health and she wouldn't have had to go behind his back hegar she finally got her tubes tied this time by a family doctor instead. She said they didn't trust her. That seemed wrong to me."],
#                             'Text_SubjectiveLit': ['I feel that I could benefit by someone assisting me in finding the accurate information needed to make the necessary decisions needed to obtain answers for any medical or mental health issue.']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['Every two years, I go to the low-income clinic in town and get a bunch of tests and an eye exam.  I also go to Planned Parenthood and get an exam and have my insurance billed for an ultrasound and cervical checkup.  I have gone to the dentist occasionally in my life.\n\n\n'],
#                             'Text_Anxiety': ["I suppose the worst thing is when a doctor lies to you or is not treating your condition properly. I've had that experience before and since then I've been a bit skittish whenever I am prescribed a new medication. "],
#                             'Text_TrustPhys': ["They don't really do anything for me so theres no need to distrust them. "],
#                             'Text_SubjectiveLit': ['I am fully capable to obtain and understand any health information and services that I would need to make any decisions with my health. ']}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I once had to undergo surgery to have my appendix removed due to acute appendicitis. It was a scary experience, but I was able to recognize the symptoms quickly and seek medical help promptly. This taught me the importance of being aware of my body and taking action when something feels off. Although it was a challenging time, I am grateful for the lessons I learned about the importance of health and listening to my body.'],
#                             'Text_Anxiety': ["I often feel anxious and worried when visiting the doctor's office because I fear being judged for my weight and lifestyle choices. I also worry about potentially being prescribed more medications or being criticized for not being able to engage in more physical activity. Additionally, I feel overwhelmed by the medical jargon and information thrown at me during appointments, which can make me feel confused and inadequate."],
#                             'Text_TrustPhys': ['I trust my primary care physician because they have always taken the time to listen to my concerns and address them with care and understanding. They have provided me with appropriate medical advice and treatment options, and I feel comfortable discussing personal health issues with them. However, there have been instances where I have felt rushed during appointments or that my concerns were not taken seriously, leading to some moments of distrust.'],
#                             'Text_SubjectiveLit': ['I would say that I have a moderate capacity to obtain and understand basic health information and services. While I do regularly visit my primary care physician and take prescription medications, my lack of physical activity and weight may impact my overall health knowledge and decision-making. I may need extra support in managing my health effectively due to these factors.']})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["I used to volunteer at my mom's nursing home when I was younger.  I saw all sorts of patients and learned about their various conditions."],
#                             'Text_Anxiety': ["I don't feel worried about visit the doctor, I just feel awkward in the room waiting my turn for the psychologist session"],
#                             'Text_TrustPhys': ['I trust my doctor because the type of type of person that he is and he is always interested in keeping me healthy so that i do not have to go see him with anything bad happening to me'],
#                             'Text_SubjectiveLit': ['With my current living conditions, I can make any kind of decision I want. Whether it would be good or bad. But I would need to make sure my family is deducted to because they help make the choice as a family. NOTICE:I tend to like my business private.']}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I once began feeling dizzy, light-headed, and had a rapid heartbeat. I recognized it as a sign of dehydration, and drank enough water to restore my balance and heart rate. '],
#                             'Text_Anxiety': ["i feel like they may ask me about physical things i deal with that i don't know enough about"],
#                             'Text_TrustPhys': ["Because I am so young and in relative good health I do not have a primary care physician because I feel there is no need. Doctors never showed any interest in me because of my obesity during my childhood. I always felt like they weren't completly honest and it was uncofortable. "],
#                             'Text_SubjectiveLit': ['I feel like I do have the capacity to obtain and to be able understand my questions that I might have about health care in general. I feel that I would be able to call someone from my insurance company or the online chat to have someone help me. ']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["I am young so I have not had many instances when my own health was in danger. There was one time when I was about 16 and I was about 10 pounds underweight. My family decided to throw a big carnival with all the fixings. I could not have been any less interested in eating than on that day. There were wings,hot dogs, ice cream, everything that could want. Laughter and shouting in excitement filled the air. People ate good food and I just sat there watching, knowing that I should eat but not feeling particularly invested. I could have just went around and enjoyed myself for the evening but I vividly remember the moment I had to go to the sheriff's department, which was across the street from my grandmothers, and sit in their cold, sterile bathroom alone. It was only about 20 minutes but felt like an eternity. I remember feeling just the faintest sliver of fear in the pit of my stomach. I knew that I needed to eat or else I was going to have to go to the ER that night. I went back to my grandmothers and had a sandwich, some wings, and turned the page on that chapter."],
#                             'Text_Anxiety': ["I feel very anxiuos because I dont have a primary doctor and I dont get regular check ups. I also feel stressed because I always feel judged when I go to the doctor's office. "],
#                             'Text_TrustPhys': ["I don't trust doctors because they tend to diagnose people with things that are not true. For instance, my son is diagnosed with ADD and he is very productive. He is a business owner of a successful barber shop."],
#                             'Text_SubjectiveLit': ['I do feel like I have the capacity to obtain, process, and understand basic health information and services because my mother was in the medical field all my life. I am able to read and look up on information presented to me to make the best decision for my health.']}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["One experience that comes to mind is when I helped my grandmother manage her diabetes. I took the time to research about the condition, attend doctor's appointments with her, and learn about proper nutrition and medication management. I made sure she stayed active and followed her healthcare plan diligently. It was a challenging but rewarding experience that taught me a lot about the importance of health literacy and advocacy."],
#                             'Text_Anxiety': ["I feel anxious and worried when visiting the doctor's office because I often feel judged or stigmatized based on my weight. I fear being shamed for my size and not receiving proper care or understanding from healthcare professionals. Additionally, I sometimes worry about not being taken seriously or dismissed due to my age or race. This can make me hesitant to seek medical help when needed."],
#                             'Text_TrustPhys': ["I don't have a primary care physician because I've never really felt the need to have one. I've always been relatively healthy and rarely get sick, so I haven't seen the necessity of having a regular doctor. Additionally, I've had negative experiences in the past with healthcare providers not taking my concerns seriously or dismissing them because of my weight. This has made me hesitant to trust doctors in general and seek medical help when needed."],
#                             'Text_SubjectiveLit': ['Honestly, I think I have a decent understanding of basic health information, but I struggle with consistently applying it to my own life. I know the importance of things like exercise and regular check-ups, but I often find it hard to prioritize my health amidst other responsibilities. I do try to take care of myself, but I know I could definitely do better. I think I could benefit from some guidance and support in this area.']})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['HER ANSWER:  "When was diagnosed with breast cancer in March 2010, I spent every hour I wasn\'t working researching and meeting with health professionals.  I was so diligent in the beginning that I actually had to stop reading in July of 2010-- I\'d reached the saturation point.  I\'ve never stopped questioning my treatments, side effects and such".\n'],
#                             'Text_Anxiety': ["I am most anxious when I don't think I'm doing what I should to stay healthy, or that I'll have a serious disease."],
#                             'Text_TrustPhys': ['Trust Person A,  April 22, 2019 2:01 PM  \nShe answers all my questions  She spends time She full fills my needs  She is friendly  She smiles  She remembers me from one appointment to next '],
#                             'Text_SubjectiveLit': ['My  wife and I are very verstile and capable of making good decisions about out health.  Would like  more about factors like disadvantages related to economics etc.  Are we poor_medium income_players or rich  ??']}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['The only time in recent memory I have had a woolly or heat stroke was when I did not get up the energy to set my air conditioning before I went to bed.  It only took a few minutes for me to start to feel the negative effects of the stifling environment.  30 minutes later I got up enough energy to get up and turn my air on.'],
#                             'Text_Anxiety': ['"That I don\'t have enough time to thoroughly discuss whatever symptoms I am having. That I haven\'t asked a very important question. That I\'m going to be put on a medication that I can\'t get a cost break on. That he is going to be worried about something he sees and that he didn\'t convey it accurately to me."'],
#                             'Text_TrustPhys': ['Reasons for your trust can be that you have been seeing the doctor for many years and have not had any major health problems recently. Or you have had a procedure and have been recovering healthily. Reasons for distrust could be that The doctor forgot an important piece of information or did not tell you all the information you would have liked to know. Or the doctor seemed apathetic towards your symptoms. '],
#                             'Text_SubjectiveLit': ['Health information can be very complex. It is important to have good advice and to ask questions. It is also good to be open and tell the truth to your doctors. ']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['Back in the 80s, for almost 4 years, I worked for a non-profit health insurance organization and had to develop training materials for people who were becoming certified as insurance salespeople. I learned a lot about deductibles, co-pays, etc, and how things have changed since the good old days.'],
#                             'Text_Anxiety': ["I am most anxious with the doctor's office when I feel sick."],
#                             'Text_TrustPhys': ['I have been seeing my primary care physician for many years and feel comfortable with him. I trust him to direct me to a specialist if needed.              '],
#                             'Text_SubjectiveLit': ["Thanks for telling me about your medical issues.  What's been bothering you the most? "]}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I remember a time when I noticed some unusual symptoms in my friend and insisted she see a doctor immediately. My intuition proved correct as she was diagnosed with a serious medical condition that required prompt treatment. I believe in being proactive about health and always look out for the well-being of those around me.'],
#                             'Text_Anxiety': ["When visiting the doctor's office, I often feel anxious and worried about my various health conditions and whether my medications are still effective. I worry about receiving new diagnoses or changes in my current treatment plan. I also feel nervous about potentially missing important information or not being able to effectively communicate my symptoms or concerns. Overall, I just want to ensure that I am doing everything possible to maintain and improve my health despite facing various challenges."],
#                             'Text_TrustPhys': ['I trust my primary care physician because they have been taking care of me for many years and have always been attentive to my health concerns. They take the time to explain things clearly and listen to my questions and worries. I appreciate their expertise and the fact that they coordinate my care with specialists when needed. Overall, I feel comfortable and well cared for with my primary care physician.'],
#                             'Text_SubjectiveLit': ['I believe I have a good understanding of basic health information and the services needed to make appropriate health decisions. I make sure to visit my primary care physician regularly, take my prescription medications as directed, and follow any medical advice given to me. While I may not engage in much physical activity, I prioritize my health and well-being by actively seeking medical help when needed and adhering to treatment plans.']})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I have always been the go to person for anything health related.  I remember once my father was complaining of jaw pain for days, from a toothache.  He was not able to make an appointment with his dentist at all, so I researched home toothache remedies and found a list of some for him to try and he tried the garlic remedy and was so happy that it took his pain away, he was so grateful to me for finding that information for him because he was so miserable. '],
#                             'Text_Anxiety': ['The possibility of having something seriously wrong that requires emergemcy surgery or that I am going to scaried my family and close friends and they might be sad or scared '],
#                             'Text_TrustPhys': ["I trust him because he's professional and appears confident in what he is doing. "],
#                             'Text_SubjectiveLit': ['I think that I know and understand the information once it is given to me but I find it hard to know what to ask or what I need to know. I have found that the general information is not always helpful or the whole story. Like my pyschiatrist should have told me taking Cytomel with synthroid would have the side effect.']}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["I sprained my ankle a few months ago and took it upon myself to learn everything I could about the healing time, possible complications, and the anatomy of the ankle in general. It's really hard to know when to go to the ER and when to just ice and elevate."],
#                             'Text_Anxiety': ['I do get more anxious at a gynecologist because i have bad experiences in the past i dont like my wiegh everbody doesnt weigh the same  heck sometimes i feel like my doctor that i have had in the past. doesnt know how is important is to get a woman healthy so they can take care of their kids  and other loved ones  i think being healthy is important for my family that i can live my best life with because in order to take care of a family my health is important'],
#                             'Text_TrustPhys': ['I do not have a physician to trust or distrust. '],
#                             'Text_SubjectiveLit': ['I feel that I have the capacity to understand my basic health information because I was raised with the belief that health is of utmost importance so I am on top of different types of information that I come across. ']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['Actually, I recently gave birth to my first child and before and after i had to my prenatal vitamins to keep my energy and health up due to the many complications that could have occurred during that time.  weir my first child the pregnancy was smooth I would have prehypertension but other than that everything went smoothly'],
#                             'Text_Anxiety': ["My cholesterol was high last time so I am afraid it will be bad this time and I don't want to take any prescription medication.  I don't want to let my doctor or myself down so I get concerned about making sure I am maintaining my health. "],
#                             'Text_TrustPhys': ['I was discouraged to know that there was health care personnel that genuinely didnt care to help their patients . I feel as if she sees me as low income and less of a patient. '],
#                             'Text_SubjectiveLit': ['I have no problem understanding instructions from the doctor and a very good memory of the visit as well as all that was said to me.  I said i have no problem accoring to this question.']}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["I remember a time when my grandmother was hospitalized due to complications from diabetes. I took on the role of coordinating her care, attending doctor's appointments, managing her medications, and researching ways to improve her quality of life. This experience taught me a lot about the importance of proactive healthcare, the impact of chronic conditions, and the significance of advocating for oneself and loved ones in the medical system. It underscored the value of prioritizing health and seeking out resources to support overall well-being."],
#                             'Text_Anxiety': ["When visiting the doctor's office, I often feel anxious about discussing my weight and any potential health issues that may arise from it. I worry about being judged or receiving negative feedback about my lifestyle choices. Additionally, I feel apprehensive about potentially needing to take prescription medications or undergo medical procedures due to any health concerns that may be identified during the visit."],
#                             'Text_TrustPhys': ['I trust my primary care physician because they take the time to listen to my concerns, provide clear explanations about my health, and involve me in decision-making regarding my treatment. They are respectful, empathetic, and make me feel comfortable during appointments. Additionally, they have a good reputation in the community and have always been responsive to my needs.'],
#                             'Text_SubjectiveLit': ['I believe I have a moderate capacity to obtain, process, and understand basic health information and services. While I may not have extensive formal education in the field, I am proactive in seeking out information when needed and am able to comprehend the basics. Additionally, I am comfortable discussing health concerns with my primary care physician and rely on their expertise to guide me in making appropriate health decisions. Overall, I value staying informed about my health and strive to make choices that support my well-being despite any limitations in my educational background.']})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I read that certain vitamins & minerals are key for brain health and pre-meditated a new diet consisting of the foods that were high in those nutrients '],
#                             'Text_Anxiety': ["I am afraid of receiving negative results of the tests that are completed on me.  But since I am someone who is generally pretty healthy, it doesn't usually worry me too much.  I preoccupied with what I look like when they take my blood pressure and it I hope to lose a little more weight so I don't have high  blood pressure anymore.  I don't like symptom checkers because I will get those symtoms - this makes me worry too.  Mostly I worry that he will give me some bad news or  will be sick one day."],
#                             'Text_TrustPhys': ['i trust my doctor because of her credentials and I feel she has my best interest at heart. '],
#                             'Text_SubjectiveLit': ['I think I have no problem reading and understanding the material in English that my health care provider may give me. However, if given verbal instructions, I am very likely to forget most of it right away.  I am also likely to feel confident in my ability to obey these instructions, but when it comes time to actually do what was instructed, my nerves get the best of me and I will forget the correct steps. I am very nervous around medical offices and professionals and will often shut down. I may also downplay any of the seriousness of my health problems to health care professionals&nbsp;']}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I understand the way doctors work, there is a section at the top of most claims I may have to bring that to there attention if they are saying Drop me from medical what may happen if I am not covered when it may happen if I wait till the next open enrollemnt periods.'],
#                             'Text_Anxiety': ["As an 18-29 year old female, under 5'4 and a person of multiracial descent you were concerned about strangers comments made to you about your race.  You were also concerned about being late or not finding a parking spot."],
#                             'Text_TrustPhys': ['I trust in my primary doctor because she listens to me and answers my questions.  She delivers the truth and take a genuine interest in me as a person. '],
#                             'Text_SubjectiveLit': ['I feel neutral about my ability.']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['When my grandfather was diagnosed with stomach cancer, I assumed the role of liaison between my Chinese-speaking grandfather and the team of English-speaking doctors. I translated information between the two parties, and as a result I learned about his illness in both languages. '],
#                             'Text_Anxiety': ["I just generally feel uncomfortable have to share my personal health struggles with anyone but myself unless it's my doctor. I also get uncomfortable when MDs underestimate my pain and/or diagnose me incorrectly. "],
#                             'Text_TrustPhys': ['My primary care physician is also my pediatrician that I have seen my whole life. He knows me personally and always remembers my history. He is sympathetic and gets me the help I need when necessary. '],
#                             'Text_SubjectiveLit': ['I feel like I can receive my health information well and aware of the options available when dealing with my health. I feel I do enough independent research to get the best possible outcome with my health conditions. ']}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['One experience that comes to mind is when I had to research and understand the side effects and interactions of several prescription medications I was taking. It was important for me to be aware of how each drug could affect my body and how they could potentially interact with each other. This experience taught me the importance of being informed about my own health and taking an active role in managing my medication regimen.'],
#                             'Text_Anxiety': ["I feel most anxious when visiting the doctor's office when I have to discuss my mental health. Opening up about my emotions and struggles can be really challenging for me, and I worry about being judged or misunderstood. Additionally, I get anxious about getting bad news regarding my physical health, especially when it comes to potential long-term implications or serious conditions. I tend to overthink and stress about the unknown outcomes during these appointments."],
#                             'Text_TrustPhys': ['I trust my primary care physician because they listen to my concerns attentively, explain medical information clearly, and involve me in the decision-making process regarding my health. They have shown genuine care and empathy towards me during appointments, which has built a strong sense of trust in their expertise and commitment to my well-being. Additionally, their professional demeanor and consistent follow-ups reassure me that I am in good hands.'],
#                             'Text_SubjectiveLit': ['I would say that I have a good capacity to obtain, process, and understand basic health information and services. I have a primary care physician whom I occasionally visit, and I take a moderate number of prescription drugs regularly, indicating that I am actively involved in managing my health. Additionally, I engage in moderate weekly physical activity, showing that I value staying healthy and active. While there is always room for improvement, I believe I have a solid foundation in making appropriate health decisions.']})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["Attempting to change the subject back to work, as Gayle obviously doesn't want to discuss anything semi-personal"],
#                             'Text_Anxiety': ["Sometimes it feels like my doctor isn't listening or it feels like my appointment is rushed.  Other times it depends on the purpose for the visit like if I am having a particularly bad chronic pain day or if I am going in for an issue that has me a little anxious like a female issue or something. "],
#                             'Text_TrustPhys': ['"I suppose I trust them as much as is necessary. I know that they are qualified and it\'s important to keep up with physicals and whatnot. But I think doctors, in general, have a bit of a god complex."'],
#                             'Text_SubjectiveLit': ['Debate coaching?! yes you would be so much better prepared for what ever weather it be a trial or a debate or even if you are trying to persuade someone to your side of an argument you could collaborate with debaters. Heres why a few reasons why debating could be good for you: 1) It will certainly help you in upcoming education because it will teach you to strive for excellence. 2) If you are going into a career that requires you to speak to jurors then you will have some prior experience 3) If you are debating a kins political opinion it will only help you become more educated on the subject and be better prepared next time.  And the professional setting could be beneficial too because as a lawyer you have to be very good at persuading jurors to your side and they are more than likely going to be stubborn.']}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["I've had a basal cell carcinoma on my leg that was removed by my dermatologist.  She told me it was nothing to worry about and had a high probability of removal with the surgery.  I did some online research when she told me what it was and confirmed what she told me.  This visit with the dermatologist was not the first exposure to the term from doctors.  I was taken to the dermatologist as a child to have a mole removed on my cheek.  This mole was precancerous.  I was taught early the importance of protecting skin.  Even on this visit, though my carcinoma was not on my face, she told me the importance of protecting my skin everywhere, not just my face.  I can't say that I've avoided the sun too much, but I do wear sunscreen and hats at the beach "],
#                             'Text_Anxiety': ['I express my anxieties about family and wish for some solutions that could help me relax'],
#                             'Text_TrustPhys': ['I trust my primary care physician because they are expected to have a code of ethics and not lie to me.'],
#                             'Text_SubjectiveLit': ['Any information the doctor tells me I will write it down as soon as possible. I do not have a lot of people to help me remember and I have a bad memory, if I write it down I can always recheck when needed.']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I work in AIDS research and recently read the experiences of numerous individuals who have lived with HIV for decades. They tell incredible stories of triumph against an apparently devastating illness while undergoing an unimaginable amount of medical treatment and therapy.'],
#                             'Text_Anxiety': ['Actually, I dislike hospitals and the smell of medical facilities the most.  The smells can make me kind of queasy.'],
# ...
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['One experience that comes to mind is when my grandmother was diagnosed with diabetes. I took it upon myself to research the condition, learn about the importance of diet and exercise in managing it, and even attended some of her medical appointments to better understand her treatment plan. I made sure she followed her prescribed medication schedule and encouraged her to make healthier choices, like going for walks together after dinner. It was a challenging time, but it taught me a lot about the impact of lifestyle choices on health and the importance of being proactive in managing medical conditions.'],
#                             'Text_Anxiety': ["When visiting the doctor's office, I often feel anxious about potentially receiving bad news regarding my health. I worry about not being able to afford any necessary treatments or medications, given my income level. Additionally, I sometimes feel anxious about not understanding medical jargon or diagnoses, which can lead to confusion and uncertainty about my health."],
#                             'Text_TrustPhys': ['I trust my primary care physician because they have always been attentive, compassionate, and knowledgeable during my appointments. They take the time to listen to my concerns and provide thorough explanations for any questions I may have. Additionally, they have helped me manage my health effectively and have shown genuine care for my well-being.'],
#                             'Text_SubjectiveLit': ['I believe I have a moderate capacity to obtain, process, and understand basic health information and services needed to make appropriate health decisions. I try to stay informed about health-related topics, but I know there is always more to learn. I make an effort to ask questions and seek clarification when needed, especially when discussing my health with medical professionals. I understand the importance of actively participating in my healthcare to ensure the best outcomes for my well-being.']})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['vommit blood…twice…..scaaaaaaaaary…..but ok……didn’t die…..hat efun……woo…..wow…..'],
#                             'Text_Anxiety': ['Getting news of cancer or some uncurable disease.'],
#                             'Text_TrustPhys': ['Trust him rather well at Farber. Sometimes he can be a little short in the amount of time to answer all questions, thus not giving him a rating of excellent.'],
#                             'Text_SubjectiveLit': ["I am competent in understanding a lot of medical issues.  I do understand that my medication has some side effects but I do have questions concerning my studies that I have read up on cortisol and adrenal fatigue I do have a question for my doctor to submit to him.  I have had conversations with an acquaintance whose husband was diagnosed and told by my doctor that it was just fictitious...He gave her manina and drugs.  I am on adrenal glandular and it helps me sleep a little better but since I cannot get the 4 test he ordered ...I don't see him anymore and refuse to pay him."]}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["When my daughter was going through a hard time, I wanted to make sure she wasn't suicidal, so I asked her a series of questions to make sure that emotionally she was ok. "],
#                             'Text_Anxiety': ["I feel incredibly anxious and afraid that the doctor will think I'm overweight and unhealthy.  Otherwise, I'm lucky for someone my age."],
#                             'Text_TrustPhys': ['I do not have a primary care physician at this time due to not being able to afford having insurance to see one. '],
#                             'Text_SubjectiveLit': ['Well I feel pretty sure that my cholesterol, sugar and blood pressure could be lower if I could have found a way to do it with out med aside effect I weigh so much but it is from all the medicine creepy maybe some knowing idea of why it is necessary would have made that part right ']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["One time I took my daughter to the doctor's office because I thought she had the flu, but it turned out she had RSV. He told me common symptoms to look out for so that I knew to take her back to the ER if she started to deteriorate. She ended up being perfectly fin, but I really appreciated all his help."],
#                             'Text_Anxiety': ['Spending too much time as wait time is inappropriate.  Not being famiar with a specific diagnosis and results, privacy requirements '],
#                             'Text_TrustPhys': ['I distrust my primary care physician because I am perceived as being a hypochondriac. Anything new that comes up, they seem to always tell me it is something new I need to take a pill for. No interest in finding the real problem or trying to do so by learning how to maintain a healthier lifestyle instead of prescribing an abundance of drugs. '],
#                             'Text_SubjectiveLit': ['Do you mean that I am my own self-advocate in need of understanding the information provided by my doctors in order to make my own decisions? ']}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I remember a few years back when I was experiencing some persistent chest pains. Instead of ignoring them, I immediately went to the emergency room to get checked out. The doctors diagnosed me with angina, a type of chest pain caused by reduced blood flow to the heart. I was prescribed medication and advised to make lifestyle changes to improve my heart health. This experience taught me the importance of listening to my body and seeking medical help when needed.'],
#                             'Text_Anxiety': ["When visiting the doctor's office, I often feel anxious about the possibility of receiving bad news regarding my health. I worry about potential health issues that may arise and the impact they could have on my quality of life. Additionally, I am concerned about the cost of medical care and prescription medications, as my income is limited. Overall, I strive to maintain good health and any news that may threaten that can trigger anxiety for me."],
#                             'Text_TrustPhys': ["I don't have a primary care physician at the moment. I've found it challenging to find a doctor that truly listens to my concerns and takes the time to explain things thoroughly. Oftentimes, I feel like doctors rush through appointments and don't address all of my health issues. This has made me hesitant to trust doctors in general, as I want someone who genuinely cares about my well-being and takes a holistic approach to my health."],
#                             'Text_SubjectiveLit': ['I believe I have a moderate capacity to obtain, process, and understand basic health information and services. I make an effort to stay informed about my medications and health concerns, but I sometimes struggle to keep up with the latest information and guidelines. I try my best to make informed decisions about my health, but I recognize that there is always room for improvement.']})}),
#   defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#               {'0': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I am an emergency physician and I am often the first stop for patients when they come in with their medical problems, both acute and chronic. I am also the mother of two young children and as such, I regularly go to places that are teeming with unknown pathogens, hence the reason for my vigilance in the first place.'],
#                             'Text_Anxiety': ['Losing my friends and gaining weight. Looking like a fool. Getting extremely embarrassed. Having a man approach me. Losing a close loved one. Being in pain. Failing every examination I have studied for. A lack of confidence. Ageing poorly. Becoming unattractive. Needing therapy. Medical attention. To move from the life I have always known. '],
#                             'Text_TrustPhys': ['I am a strong believer  in the core values of customer service, my husband and I own our own company so we know first hand the importance of keeping our customers happy and the negative impact of providing poor customer service.  I believe that an excellent customer experience would consist of: \n\n~ Maintaining all levels of customer satisfaction in a diverse market \n~ Improving customer service communication \n~ Offering well trained staff \n~ Encouraging staff with rewards for quality customer service \n~ Develop a good understanding of staff needs and improving training  \n'],
#                             'Text_SubjectiveLit': ["I feel pretty confident about my ability in that specific area.  I can get around a web page pretty well to find health information.  I'm not super healthy, which may sound odd as I just said my health is very important to me.  Maybe I should clarify: I'm overweight and out of shape,but I don't have high blood pressure or diabetes,yet.  I have a pretty good idea how to eat but I don't do it right.  Hormonally over my life I had a strange balance that was mis-diagnosed and over-treated.  So now its under-treated and I'm having issues.  My bone density is enviable though (knock on wood) and I'm pre-menopausal.  I need moderate but,good medical advice and good proliferating of what advice I need to take with the advice of said doctor."]}),
#                '1': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ['I was working at a local hospital in the emergency department as a registration specialist. There was this middle aged patient who came and followed all of the rules that the doctors and nurses initially set out for him and still got no improvement. He kept coming back with the same symptoms of SOB and anoerexia. His labs showed no improvement but the patient seemed to lose lots of weight. The doctor ordered an MRI. He had been getting treated for pneumonia for "months" despite the fact that he had lost over 30lbs. The biopsy showed he had adenotic cancer. And this is because he was seeing the records of labs and for me I noticed the patient was had reported significant weight loss but the doctors never ordered a MRI. Instead I suggested the PA order a MRI based on his symptoms and his past medical records.'],
#                             'Text_Anxiety': ["Sometimes I feel that the doctors want to judge me about my weight and not really get to the cause of the problem.  I don't feel like I am a number or statistic so when they can recommend exercise and then address my concerns, that would make me more at ease. "],
#                             'Text_TrustPhys': ['I know its hard for a person of color, to get fair consideration, you are assumed to be  on welfafe, drugs, illigitimate offspring metal illness and many more \thelpless conditions even though you maybe very intelligent and together. I say that everyday my strength is my trust in the Creator, you come in this world by yourself you leave the same way, You will answer to him not the psychiatrist, psychologists, or the gov. '],
#                             'Text_SubjectiveLit': ['Obtaining and processing health information is important, however I feel that I may be provided incorrect or outdated information from my providers. I also review and sometimes research information on my own.']}),
#                '2': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["I had a particularly bad case of bronchitis and laryngitis when I was about 4. My mother, who was a nurse, was there to take care of me and monitor my condition. I ended up going to the hospital because I was wheezing so badly with each breath and almost couldn't get air in. I remember the nebulizer treatments and the terrible tasting pills that I had to take for the infection. At one point, they thought I was getting better and tried to send us home, but my temperature spiked again, and I was allowed to stay in the hospital for longer. My mother was instrumental in my care, because she was there to catch my reaction to certain medications, ask questions that I couldn't have articulated for myself, and inform the staff of my prior reactions to certain medications. "],
#                             'Text_Anxiety': ['There are several things that contribute to my anxiety at the doctor’s office. When my temperature spikes, it can trigger feelings and emotions. I feel stuck in my body. I need the staff and physician to not panic but to be calm and let me know they are taking actions to lower my temperature. I need to know that their actions are beneficial to my situation. '],
#                             'Text_TrustPhys': ['I trust her because she takes time to explain things to me. She truly seems interested in my health and overall well-being. While there have been times I felt she may not have wanted to listen to my explanation for my symptoms, she eventually came around and then of course started giving feedback on what I need to do.\n'],
#                             'Text_SubjectiveLit': ['No worries in that department.']}),
#                '3': defaultdict(<function __main__.regular_to_defaultdict.<locals>.<lambda>()>,
#                            {'Text_Numeracy': ["There was a time when my father was diagnosed with diabetes, and I took on the responsibility of learning everything I could about the condition. I spent hours researching about proper nutrition, exercise, and medication management to help him lead a healthier lifestyle. I even attended his doctor's appointments to ask questions and ensure he was receiving the best care possible. This experience instilled in me the importance of taking control of one's health and being proactive in managing medical issues."],
#                             'Text_Anxiety': ["When I visit the doctor's office, I often feel anxious about the potential for receiving bad news regarding my health. I worry about not being able to maintain my current level of health and fitness, as living in the best possible health is a top priority for me. Additionally, I sometimes fear being judged or stigmatized by healthcare providers due to my weight or other aspects of my identity."],
#                             'Text_TrustPhys': ['I trust my primary care physician because they have consistently shown empathy, compassion, and expertise in their field. They take the time to listen to my concerns, provide thorough explanations, and involve me in decision-making regarding my health. Additionally, they have a holistic approach to healthcare, focusing on preventive measures and overall well-being rather than just treating symptoms.'],
#                             'Text_SubjectiveLit': ['I believe I have a strong capacity to obtain, process, and understand basic health information and services. Despite having only some college education, I make sure to stay informed by reading reliable sources, asking questions during my occasional visits to my primary care physician, and actively seeking out information on maintaining good health. I prioritize my health and well-being, and I am dedicated to making informed decisions to live a healthy lifestyle.']})})]]

# %%
all_similarities = {f"cluster_{j}" : [] for j in range(best_k)}

for clust in range(len(all_labels)):
    similarities = []
    for i, person in enumerate(all_labels[clust]):
        label = [person["Text_Numeracy"], person["Text_Anxiety"], person["Text_TrustPhys"], person["Text_SubjectiveLit"]]
        
        answer_models = [
            [all_responses[clust][i][str(model_idx)]["Text_Numeracy"],
             all_responses[clust][i][str(model_idx)]["Text_Anxiety"],
             all_responses[clust][i][str(model_idx)]["Text_TrustPhys"],
             all_responses[clust][i][str(model_idx)]["Text_SubjectiveLit"]]
            for model_idx in range(len(models))
        ]

        scores = [[] for _ in range(len(models))]  # 存放5个模型的分数

        for j in range(len(label)):
            for model_idx in range(len(models)):
                scores[model_idx].append(calculate_similarity(label[j], answer_models[model_idx][j]))

        similarities.append(scores)  # 包含所有模型的分数
    all_similarities[f"cluster_{clust}"] = similarities
# Out:
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\howar\Anaconda3\envs\gpt\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
''' 
structure of all_similarities
{
    "cluster_0": [
        # Person 0 in cluster_0
        [
            [similarity_Numeracy_model0, similarity_Anxiety_model0, similarity_TrustPhys_model0, similarity_SubjectiveLit_model0],  # model 0 scores
            [similarity_Numeracy_model1, similarity_Anxiety_model1, similarity_TrustPhys_model1, similarity_SubjectiveLit_model1],  # model 1 scores
            [similarity_Numeracy_model2, similarity_Anxiety_model2, similarity_TrustPhys_model2, similarity_SubjectiveLit_model2],  # model 2 scores
            [similarity_Numeracy_model3, similarity_Anxiety_model3, similarity_TrustPhys_model3, similarity_SubjectiveLit_model3],  # model 3 scores
            [similarity_Numeracy_regular, similarity_Anxiety_regular, similarity_TrustPhys_regular, similarity_SubjectiveLit_regular]  # regular model scores
        ],
        # Person 1 in cluster_0
        [
            [similarity_Numeracy_model0, similarity_Anxiety_model0, similarity_TrustPhys_model0, similarity_SubjectiveLit_model0],
            [similarity_Numeracy_model1, similarity_Anxiety_model1, similarity_TrustPhys_model1, similarity_SubjectiveLit_model1],
            [similarity_Numeracy_model2, similarity_Anxiety_model2, similarity_TrustPhys_model2, similarity_SubjectiveLit_model2],
            [similarity_Numeracy_model3, similarity_Anxiety_model3, similarity_TrustPhys_model3, similarity_SubjectiveLit_model3],
            [similarity_Numeracy_regular, similarity_Anxiety_regular, similarity_TrustPhys_regular, similarity_SubjectiveLit_regular]
        ],
        # More people in cluster_0
    ],
    "cluster_1": [
        # Similar structure as cluster_0
    ],
    # More clusters
}

'''

# %%
# Calculate average similarities for each model in each cluster
best_models = {}

for clust, sim_list in all_similarities.items():
    cluster_similarities = np.array(sim_list)
    average_model_similarities = np.mean(cluster_similarities, axis=(0, 1))  # Axis 0 is people, axis 1 is fields

    best_model_idx = np.argmax(average_model_similarities)
    best_models[clust] = best_model_idx

    print(f"Cluster {clust}, Best model: model{best_model_idx} with average similarity: {average_model_similarities[best_model_idx]}")

# Print the best models for all clusters
print("Best models for all clusters:", best_models)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 # Calculate average similarities for each model in each cluster
#       2 best_models = {}
# ----> 4 for clust, sim_list in all_similarities.items():
#       5     cluster_similarities = np.array(sim_list)
#       6     average_model_similarities = np.mean(cluster_similarities, axis=(0, 1))  # Axis 0 is people, axis 1 is fields
#
# NameError: name 'all_similarities' is not defined

# %% [markdown]
# ### 2. LLM as judge? comparing responses between label & different models
#
# Dimensions：
# 1. similarity on decision
# 2. similarity on personality
# 3. hallucination
# 4. stability

# %%
judger = OpenAI()
system_judger_prompt = "You are a professional psychologist with extensive experience in evaluating textual responses for various psychological and cognitive dimensions. "

def get_response(judger, message):
    response = judger.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_judger_prompt},
            {"role": "user", "content": message}
        ]
    )
    return response.choices[0].message.content

def extract_numeric_score(response_text):
    match = re.search(r"(\d+(\.\d+)?)", response_text)
    if match:
        return float(match.group(1))
    else:
        return 0.0
    
def calculate_similarity_llm(label, answer):
    dimensions = ["similarity on decision", "similarity on personality", "hallucination", "stability"]
    scores = []
    for dimension in dimensions:
        message = f"Evaluate the following model response based on the dimension of '{dimension}' comparing to the label response:\n\nLabel response: {label}\nModel response: {answer}\n\nScore (1-10). Please only output the number."
        score_text = get_response(judger, message)
        score = extract_numeric_score(score_text)
        scores.append(score)
    return sum(scores) / len(scores)

# %%
all_similarities = {f"cluster_{j}" : [] for j in range(best_k)}

for clust in range(len(all_labels)):
    similarities = []
    for i, person in enumerate(all_labels[clust]):
        label = [person["Text_Numeracy"], person["Text_Anxiety"], person["Text_TrustPhys"], person["Text_SubjectiveLit"]]
        
        answer_models = [
            [all_responses[clust][i][str(model_idx)]["Text_Numeracy"],
             all_responses[clust][i][str(model_idx)]["Text_Anxiety"],
             all_responses[clust][i][str(model_idx)]["Text_TrustPhys"],
             all_responses[clust][i][str(model_idx)]["Text_SubjectiveLit"]]
            for model_idx in range(5)
        ]

        scores = [[] for _ in range(5)]  # 存放5个模型的分数

        for j in range(len(label)):
            for model_idx in range(5):
                scores[model_idx].append(calculate_similarity_llm(label[j], answer_models[model_idx][j]))

        similarities.append(scores)  # 包含所有模型的分数
    all_similarities[f"cluster_{clust}"] = similarities

# %%
import numpy as np

best_models = {}
all_scores = {}

for clust, sim_list in all_similarities.items():
    cluster_similarities = np.array(sim_list)
    
    # Calculate the mean similarity for each model across all fields for each person
    mean_similarities_per_person = np.mean(cluster_similarities, axis=2)
    
    # Calculate the average similarity for each model across all people
    average_model_similarities = np.mean(mean_similarities_per_person, axis=0)
    
    best_model_idx = np.argmax(average_model_similarities)
    best_models[clust] = best_model_idx
    all_scores[clust] = average_model_similarities

    print(f"Cluster {clust}, Model scores: {average_model_similarities}")
    print(f"Cluster {clust}, Best model: model{best_model_idx} with average similarity: {average_model_similarities[best_model_idx]}")

# Print the best models for all clusters
print("Best models for all clusters:", best_models)
# Out:
# Cluster cluster_0, Model scores: [2.6625  2.725   2.7375  3.35    3.49375]
# Cluster cluster_0, Best model: model4 with average similarity: 3.49375
# Cluster cluster_1, Model scores: [2.425    2.771875 2.728125 3.378125 3.84375 ]
# Cluster cluster_1, Best model: model4 with average similarity: 3.84375
# Cluster cluster_2, Model scores: [2.7421875 2.7625    2.5765625 3.4375    3.75     ]
# Cluster cluster_2, Best model: model4 with average similarity: 3.75
# Best models for all clusters: {'cluster_0': 4, 'cluster_1': 4, 'cluster_2': 4}
