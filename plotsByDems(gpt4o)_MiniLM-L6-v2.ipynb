# %% [markdown]
# ## Plot by Demographics
#
# Inspired by https://arxiv.org/abs/2410.19599

# %%
import pandas as pd

# %%
Dsim = pd.read_csv("similarity_calculations_4o_all_sbert_all-MiniLM-L6-v2.csv")

Dsim.head()
# Out:
#    Unnamed: 0  Sample Index                  Condition            Question  \
# 0           0             0                all_4.jsonl  Text_SubjectiveLit
# 1           1             0                all_4.jsonl        Text_Anxiety
# 2           2             0                all_4.jsonl       Text_Numeracy
# 3           3             0                all_4.jsonl      Text_TrustPhys
# 4           4             0  conditioning_on_all.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.199660  I feel fairly confident in my ability to obtai...
# 1    0.458754  When I visit the doctor's office, I sometimes ...
# 2    0.289328  Sure, there was a time when a close friend was...
# 3    0.560838  I generally trust my primary care physician be...
# 4    0.259504  I feel quite confident in my ability to obtain...
#
#                                           True Label
# 0  Life is great and we all must pick what we wan...
# 1  How doctors decide to take care of uses and pr...
# 2  The girl I'm engaged to has health problems at...
# 3  Doctors and nurses ppl must have full trust in...
# 4  Life is great and we all must pick what we wan...

# %%
from utils import *
EXPERIMENT_TYPE = 'Demographic + Behavioral + Psychological'
file_path = 'Data/Data_SurveyPlusDemographics.txt'
data = pd.read_csv(file_path, sep='\t', encoding='ISO-8859-1')

# Data preprocess
data, psychological_list = convert_to_natural_language(data)
data, fipi_columns = split_fipi_responses(data)
data.drop(columns=['FIPI_response'], inplace=True, errors='ignore')
psychological_list.extend(fipi_columns)


train_data = select_experiment_data(data, EXPERIMENT_TYPE)
train_data = process_data_based_on_experiment(train_data, EXPERIMENT_TYPE)

# add labels column
label_columns = ['Text_SubjectiveLit', 'Text_Anxiety', 'Text_Numeracy', 'Text_TrustPhys']
train_data = pd.concat([train_data, data[label_columns]], axis=1)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_62080\1438049294.py:4: DtypeWarning: Columns (115) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, sep='\t', encoding='ISO-8859-1')
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(clean_numeric)
# c:\Users\howar\OneDrive\Documents\GitHub\psych-agent-llm\utils.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.cut(df[column], bins=[0, 2, 4, 5], labels=['Disagree', 'Neutral', 'Agree'])

# %%
train_data.head()
# Out:
#      D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8     HC_1     HC_2  ...  \
# 0  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152    Agree    Agree  ...
# 1  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150    Agree    Agree  ...
# 2  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160  Neutral  Neutral  ...
# 3  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168  Neutral  Neutral  ...
# 4  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220    Agree    Agree  ...
#
#       HC_5                                    FIPI_1_response  \
# 0  Neutral  You disagree that you are extraverted and enth...
# 1    Agree  You unknown that you are extraverted and enthu...
# 2  Neutral  You strongly agree that you are extraverted an...
# 3  Neutral  You disagree that you are extraverted and enth...
# 4  Neutral  You disagree that you are extraverted and enth...
#
#                                      FIPI_2_response  \
# 0  You strongly agree that you are agreeable and ...
# 1       You unknown that you are agreeable and kind.
# 2       You unknown that you are agreeable and kind.
# 3       You unknown that you are agreeable and kind.
# 4       You unknown that you are agreeable and kind.
#
#                                      FIPI_3_response  \
# 0  You strongly agree that you are dependable and...
# 1  You unknown that you are dependable and organi...
# 2  You unknown that you are dependable and organi...
# 3  You unknown that you are dependable and organi...
# 4  You unknown that you are dependable and organi...
#
#                                      FIPI_4_response  \
# 0  You unknown that you are emotionally stable an...
# 1  You strongly agree that you are emotionally st...
# 2  You unknown that you are emotionally stable an...
# 3  You agree that you are emotionally stable and ...
# 4  You agree that you are emotionally stable and ...
#
#                                      FIPI_5_response  \
# 0  You unknown that you are open to experience an...
# 1  You agree that you are open to experience and ...
# 2  You unknown that you are open to experience an...
# 3  You unknown that you are open to experience an...
# 4  You unknown that you are open to experience an...
#
#                                   Text_SubjectiveLit  \
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...
#
#                                         Text_Anxiety  \
# 0  With some health care providers in the past, I...
# 1  I worry that I won't get the full attention of...
# 2  I do not like to wait for test results to say ...
# 3  The thing that makes me most anxious is wonder...
# 4  I just get nervous having to sit in doctor's o...
#
#                                        Text_Numeracy  \
# 0  A friend had been given antibiotic eye drops f...
# 1  Just normal doctor visits and testing.  not wo...
# 2  I tried to use my math skills the best that I ...
# 3  I studied athletic training in college, and I'...
# 4  Every time I researched my symptoms myself and...
#
#                                       Text_TrustPhys
# 0  She never seems rushed with me, and she will a...
# 1  My doctor wants to give his all, but the time ...
# 2  I like that the dr takes the time to listen an...
# 3  Typically when I see a doctor, they are a medi...
# 4  I trust my doctor because he is highly trained...
#
# [5 rows x 22 columns]

# %%
train_data.columns
# Out:
# Index(['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'Dmed_7', 'Dmed_8', 'HC_1', 'HC_2',
#        'HC_3', 'HC_4', 'HC_5', 'FIPI_1_response', 'FIPI_2_response',
#        'FIPI_3_response', 'FIPI_4_response', 'FIPI_5_response',
#        'Text_SubjectiveLit', 'Text_Anxiety', 'Text_Numeracy',
#        'Text_TrustPhys'],
#       dtype='object')

# %%
Dtrain = train_data[["D1", "D2","D3","D4","D5","D6","Dmed_7","Dmed_8","Text_SubjectiveLit", "Text_Anxiety", "Text_Numeracy","Text_TrustPhys"]]
Dtrain["id"] = Dtrain.index

Dtrain.head()
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_62080\3733813787.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dtrain["id"] = Dtrain.index
#      D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 1  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150
# 2  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160
# 3  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168
# 4  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220
#
#                                   Text_SubjectiveLit  \
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...
#
#                                         Text_Anxiety  \
# 0  With some health care providers in the past, I...
# 1  I worry that I won't get the full attention of...
# 2  I do not like to wait for test results to say ...
# 3  The thing that makes me most anxious is wonder...
# 4  I just get nervous having to sit in doctor's o...
#
#                                        Text_Numeracy  \
# 0  A friend had been given antibiotic eye drops f...
# 1  Just normal doctor visits and testing.  not wo...
# 2  I tried to use my math skills the best that I ...
# 3  I studied athletic training in college, and I'...
# 4  Every time I researched my symptoms myself and...
#
#                                       Text_TrustPhys  id
# 0  She never seems rushed with me, and she will a...   0
# 1  My doctor wants to give his all, but the time ...   1
# 2  I like that the dr takes the time to listen an...   2
# 3  Typically when I see a doctor, they are a medi...   3
# 4  I trust my doctor because he is highly trained...   4

# %%
Dtrainlong = pd.wide_to_long(Dtrain, "Text_", i="id", j="topic", suffix="\D+").reset_index()

Dtrainlong["topic"] = "Text_" + Dtrainlong["topic"].astype(str)

# %%
Dtrainlong.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 1   1  Text_SubjectiveLit  22.0  2.0  1.0  4.0  3.0  1.0    29.0    150
# 2   2  Text_SubjectiveLit  33.0  2.0  1.0  6.0  6.0  1.0    32.0    160
# 3   3  Text_SubjectiveLit  17.0  2.0  1.0  5.0  6.0  1.0    31.0    168
# 4   4  Text_SubjectiveLit  17.0  1.0  1.0  4.0  1.0  1.0    34.0    220
#
#                                                Text_
# 0  I believe that I understand most of what my he...
# 1  I feel like I can understand 90% of what is be...
# 2  I feel that while I am not a health expert I d...
# 3  I feel fairly confident that when I see medica...
# 4   I am okay with it for the most part, but I of...

# %%
Dsim.head()
# Out:
#    Unnamed: 0  Sample Index                  Condition            Question  \
# 0           0             0                all_4.jsonl  Text_SubjectiveLit
# 1           1             0                all_4.jsonl        Text_Anxiety
# 2           2             0                all_4.jsonl       Text_Numeracy
# 3           3             0                all_4.jsonl      Text_TrustPhys
# 4           4             0  conditioning_on_all.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.199660  I feel fairly confident in my ability to obtai...
# 1    0.458754  When I visit the doctor's office, I sometimes ...
# 2    0.289328  Sure, there was a time when a close friend was...
# 3    0.560838  I generally trust my primary care physician be...
# 4    0.259504  I feel quite confident in my ability to obtain...
#
#                                           True Label
# 0  Life is great and we all must pick what we wan...
# 1  How doctors decide to take care of uses and pr...
# 2  The girl I'm engaged to has health problems at...
# 3  Doctors and nurses ppl must have full trust in...
# 4  Life is great and we all must pick what we wan...

# %%
D = Dtrainlong.merge(Dsim, left_on=["topic","Text_"], right_on=["Question","True Label"])

D.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 1   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 2   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 3   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
# 4   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152
#
#                                                Text_  Unnamed: 0  \
# 0  I believe that I understand most of what my he...       63360
# 1  I believe that I understand most of what my he...       63364
# 2  I believe that I understand most of what my he...       63368
# 3  I believe that I understand most of what my he...       63372
# 4  I believe that I understand most of what my he...       63376
#
#    Sample Index                         Condition            Question  \
# 0          1980                       all_4.jsonl  Text_SubjectiveLit
# 1          1980         conditioning_on_all.jsonl  Text_SubjectiveLit
# 2          1980        holdout_Text_Anxiety.jsonl  Text_SubjectiveLit
# 3          1980       holdout_Text_Numeracy.jsonl  Text_SubjectiveLit
# 4          1980  holdout_Text_SubjectiveLit.jsonl  Text_SubjectiveLit
#
#    Similarity                                 Generated Response  \
# 0    0.658386  I feel quite capable of obtaining and understa...
# 1    0.598706  I feel quite confident in my ability to obtain...
# 2    0.595097  I feel quite confident in my ability to obtain...
# 3    0.679378  I feel fairly confident in my ability to obtai...
# 4    0.623421  I feel quite capable when it comes to obtainin...
#
#                                           True Label
# 0  I believe that I understand most of what my he...
# 1  I believe that I understand most of what my he...
# 2  I believe that I understand most of what my he...
# 3  I believe that I understand most of what my he...
# 4  I believe that I understand most of what my he...

# %%
# Set up the demographics based on our paper
#D["Age_bin"] = (D["D1"] <= 38).astype(int)
D["Age"] = (D["D1"] <= 32).astype(int)

D["Gender"] = (D["D2"] == 1).astype(int)
D["Race"] = (D["D3"] == 1).astype(int)
D["Education"] = (D["D4"] >= 5).astype(int)
D["Income"] = (D["D5"] >= 4).astype(int)

D.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  ...  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 1   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 2   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 3   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 4   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
#
#                           Condition            Question  Similarity  \
# 0                       all_4.jsonl  Text_SubjectiveLit    0.658386
# 1         conditioning_on_all.jsonl  Text_SubjectiveLit    0.598706
# 2        holdout_Text_Anxiety.jsonl  Text_SubjectiveLit    0.595097
# 3       holdout_Text_Numeracy.jsonl  Text_SubjectiveLit    0.679378
# 4  holdout_Text_SubjectiveLit.jsonl  Text_SubjectiveLit    0.623421
#
#                                   Generated Response  \
# 0  I feel quite capable of obtaining and understa...
# 1  I feel quite confident in my ability to obtain...
# 2  I feel quite confident in my ability to obtain...
# 3  I feel fairly confident in my ability to obtai...
# 4  I feel quite capable when it comes to obtainin...
#
#                                           True Label  Age Gender Race  \
# 0  I believe that I understand most of what my he...    1      0    1
# 1  I believe that I understand most of what my he...    1      0    1
# 2  I believe that I understand most of what my he...    1      0    1
# 3  I believe that I understand most of what my he...    1      0    1
# 4  I believe that I understand most of what my he...    1      0    1
#
#    Education  Income
# 0          1       0
# 1          1       0
# 2          1       0
# 3          1       0
# 4          1       0
#
# [5 rows x 23 columns]

# %%
D["Condition"] = D["Condition"].str.replace("json_datasets_200/", "")
D["Condition"] = D["Condition"].str.replace(".jsonl", "")
D["Condition"] = D["Condition"].str.replace("_Text_Anxiety", "")
D["Condition"] = D["Condition"].str.replace("_Text_Numeracy", "")
D["Condition"] = D["Condition"].str.replace("_Text_SubjectiveLit", "")
D["Condition"] = D["Condition"].str.replace("_Text_TrustPhys", "")
D.head()
# Out:
#    id               topic    D1   D2   D3   D4   D5   D6  Dmed_7 Dmed_8  ...  \
# 0   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 1   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 2   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 3   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
# 4   0  Text_SubjectiveLit  21.0  2.0  1.0  6.0  1.0  1.0    30.0    152  ...
#
#              Condition            Question  Similarity  \
# 0                all_4  Text_SubjectiveLit    0.658386
# 1  conditioning_on_all  Text_SubjectiveLit    0.598706
# 2              holdout  Text_SubjectiveLit    0.595097
# 3              holdout  Text_SubjectiveLit    0.679378
# 4              holdout  Text_SubjectiveLit    0.623421
#
#                                   Generated Response  \
# 0  I feel quite capable of obtaining and understa...
# 1  I feel quite confident in my ability to obtain...
# 2  I feel quite confident in my ability to obtain...
# 3  I feel fairly confident in my ability to obtai...
# 4  I feel quite capable when it comes to obtainin...
#
#                                           True Label  Age Gender Race  \
# 0  I believe that I understand most of what my he...    1      0    1
# 1  I believe that I understand most of what my he...    1      0    1
# 2  I believe that I understand most of what my he...    1      0    1
# 3  I believe that I understand most of what my he...    1      0    1
# 4  I believe that I understand most of what my he...    1      0    1
#
#    Education  Income
# 0          1       0
# 1          1       0
# 2          1       0
# 3          1       0
# 4          1       0
#
# [5 rows x 23 columns]

# %%
D.Age.describe()
# Out:
# count    266768.000000
# mean          0.709950
# std           0.453786
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: Age, dtype: float64

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Age', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   6.365850  2.127691e-10
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   8.091119  7.469053e-16
# 2   Text_SubjectiveLit              holdout  t-test  15.005223  1.329624e-50
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   9.246237  3.452161e-20
# 4   Text_SubjectiveLit     no_system_prompt  t-test   6.918082  5.192844e-12
# 5         Text_Anxiety                all_4  t-test   3.094662  1.982520e-03
# 6         Text_Anxiety  conditioning_on_all  t-test   7.311613  3.092968e-13
# 7         Text_Anxiety              holdout  t-test  10.861794  2.124521e-27
# 8         Text_Anxiety   Baseline Zero Shot  t-test   7.832256  5.917057e-15
# 9         Text_Anxiety     no_system_prompt  t-test   5.842434  5.498221e-09
# 10       Text_Numeracy                all_4  t-test  -3.134957  1.730270e-03
# 11       Text_Numeracy  conditioning_on_all  t-test   1.590443  1.118012e-01
# 12       Text_Numeracy              holdout  t-test  -4.847494  1.261171e-06
# 13       Text_Numeracy   Baseline Zero Shot  t-test   1.790114  7.350124e-02
# 14       Text_Numeracy     no_system_prompt  t-test   0.438826  6.608090e-01
# 15      Text_TrustPhys                all_4  t-test   5.801488  7.006742e-09
# 16      Text_TrustPhys  conditioning_on_all  t-test   9.416889  7.119811e-21
# 17      Text_TrustPhys              holdout  t-test  13.966409  4.180460e-44
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  10.558131  9.141767e-26
# 19      Text_TrustPhys     no_system_prompt  t-test   8.099189  7.011901e-16
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11        False
# 12         True
# 13        False
# 14        False
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation



sns.displot(
    D, x="Similarity", hue="Race", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Race', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_62080\324857929.py:17: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Race', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Race', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   4.987522  6.303567e-07
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   1.560975  1.185857e-01
# 2   Text_SubjectiveLit              holdout  t-test   9.803320  1.211390e-22
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   3.329981  8.741766e-04
# 4   Text_SubjectiveLit     no_system_prompt  t-test   4.614910  4.020778e-06
# 5         Text_Anxiety                all_4  t-test   0.087408  9.303506e-01
# 6         Text_Anxiety  conditioning_on_all  t-test  -0.574422  5.657049e-01
# 7         Text_Anxiety              holdout  t-test   0.102270  9.185435e-01
# 8         Text_Anxiety   Baseline Zero Shot  t-test  -1.355070  1.754488e-01
# 9         Text_Anxiety     no_system_prompt  t-test  -0.720006  4.715511e-01
# 10       Text_Numeracy                all_4  t-test   6.431366  1.359471e-10
# 11       Text_Numeracy  conditioning_on_all  t-test  -0.213540  8.309133e-01
# 12       Text_Numeracy              holdout  t-test  11.336248  1.028836e-29
# 13       Text_Numeracy   Baseline Zero Shot  t-test   0.893164  3.718060e-01
# 14       Text_Numeracy     no_system_prompt  t-test   3.952177  7.832954e-05
# 15      Text_TrustPhys                all_4  t-test   0.169466  8.654364e-01
# 16      Text_TrustPhys  conditioning_on_all  t-test  -2.911832  3.607169e-03
# 17      Text_TrustPhys              holdout  t-test   0.416432  6.770977e-01
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -1.717772  8.589252e-02
# 19      Text_TrustPhys     no_system_prompt  t-test   0.256515  7.975626e-01
#
#     Significant
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10         True
# 11        False
# 12         True
# 13        False
# 14         True
# 15        False
# 16         True
# 17        False
# 18        False
# 19        False

# %%
sns.displot(
    D, x="Similarity", hue="Age", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Age', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_62080\3306198146.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Age', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Age', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   6.365850  2.127691e-10
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   8.091119  7.469053e-16
# 2   Text_SubjectiveLit              holdout  t-test  15.005223  1.329624e-50
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   9.246237  3.452161e-20
# 4   Text_SubjectiveLit     no_system_prompt  t-test   6.918082  5.192844e-12
# 5         Text_Anxiety                all_4  t-test   3.094662  1.982520e-03
# 6         Text_Anxiety  conditioning_on_all  t-test   7.311613  3.092968e-13
# 7         Text_Anxiety              holdout  t-test  10.861794  2.124521e-27
# 8         Text_Anxiety   Baseline Zero Shot  t-test   7.832256  5.917057e-15
# 9         Text_Anxiety     no_system_prompt  t-test   5.842434  5.498221e-09
# 10       Text_Numeracy                all_4  t-test  -3.134957  1.730270e-03
# 11       Text_Numeracy  conditioning_on_all  t-test   1.590443  1.118012e-01
# 12       Text_Numeracy              holdout  t-test  -4.847494  1.261171e-06
# 13       Text_Numeracy   Baseline Zero Shot  t-test   1.790114  7.350124e-02
# 14       Text_Numeracy     no_system_prompt  t-test   0.438826  6.608090e-01
# 15      Text_TrustPhys                all_4  t-test   5.801488  7.006742e-09
# 16      Text_TrustPhys  conditioning_on_all  t-test   9.416889  7.119811e-21
# 17      Text_TrustPhys              holdout  t-test  13.966409  4.180460e-44
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  10.558131  9.141767e-26
# 19      Text_TrustPhys     no_system_prompt  t-test   8.099189  7.011901e-16
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11        False
# 12         True
# 13        False
# 14        False
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True

# %%
sns.displot(
    D, x="Similarity", hue="Gender", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Gender', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_62080\3657184094.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Gender', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Gender', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   4.248729  2.185515e-05
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   3.737932  1.873762e-04
# 2   Text_SubjectiveLit              holdout  t-test   9.152779  6.019836e-20
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   3.263661  1.106575e-03
# 4   Text_SubjectiveLit     no_system_prompt  t-test   4.330039  1.517809e-05
# 5         Text_Anxiety                all_4  t-test   3.484453  4.970163e-04
# 6         Text_Anxiety  conditioning_on_all  t-test   1.711019  8.713423e-02
# 7         Text_Anxiety              holdout  t-test   6.675424  2.523987e-11
# 8         Text_Anxiety   Baseline Zero Shot  t-test   1.755253  7.927050e-02
# 9         Text_Anxiety     no_system_prompt  t-test   3.503695  4.624621e-04
# 10       Text_Numeracy                all_4  t-test   1.905894  5.671271e-02
# 11       Text_Numeracy  conditioning_on_all  t-test   0.293943  7.688120e-01
# 12       Text_Numeracy              holdout  t-test   4.426157  9.635597e-06
# 13       Text_Numeracy   Baseline Zero Shot  t-test   2.213032  2.693475e-02
# 14       Text_Numeracy     no_system_prompt  t-test   3.197579  1.392974e-03
# 15      Text_TrustPhys                all_4  t-test  -0.897871  3.692938e-01
# 16      Text_TrustPhys  conditioning_on_all  t-test  -2.206722  2.737458e-02
# 17      Text_TrustPhys              holdout  t-test  -3.392048  6.949462e-04
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -1.145775  2.519381e-01
# 19      Text_TrustPhys     no_system_prompt  t-test  -0.526576  5.985097e-01
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6         False
# 7          True
# 8         False
# 9          True
# 10        False
# 11        False
# 12         True
# 13         True
# 14         True
# 15        False
# 16         True
# 17         True
# 18        False
# 19        False

# %%
sns.displot(
    D, x="Similarity", hue="Education", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Education', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_62080\4058203010.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Education', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value = perform_stat_test(subset, 'Education', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")


results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic       p-value  \
# 0   Text_SubjectiveLit                all_4  t-test   5.901883  3.736929e-09
# 1   Text_SubjectiveLit  conditioning_on_all  t-test   6.467146  1.055691e-10
# 2   Text_SubjectiveLit              holdout  t-test  12.087237  1.453342e-33
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test   8.261764  1.659767e-16
# 4   Text_SubjectiveLit     no_system_prompt  t-test   8.298896  1.218249e-16
# 5         Text_Anxiety                all_4  t-test   2.684764  7.272597e-03
# 6         Text_Anxiety  conditioning_on_all  t-test   3.142797  1.679326e-03
# 7         Text_Anxiety              holdout  t-test   4.438287  9.097066e-06
# 8         Text_Anxiety   Baseline Zero Shot  t-test   3.227435  1.253915e-03
# 9         Text_Anxiety     no_system_prompt  t-test   2.840096  4.520971e-03
# 10       Text_Numeracy                all_4  t-test   1.607520  1.079782e-01
# 11       Text_Numeracy  conditioning_on_all  t-test  -1.768243  7.705692e-02
# 12       Text_Numeracy              holdout  t-test   1.066255  2.863162e-01
# 13       Text_Numeracy   Baseline Zero Shot  t-test   0.866408  3.862914e-01
# 14       Text_Numeracy     no_system_prompt  t-test   0.012467  9.900532e-01
# 15      Text_TrustPhys                all_4  t-test   0.929131  3.528484e-01
# 16      Text_TrustPhys  conditioning_on_all  t-test   2.263845  2.360935e-02
# 17      Text_TrustPhys              holdout  t-test   1.903246  5.701709e-02
# 18      Text_TrustPhys   Baseline Zero Shot  t-test   2.614925  8.940832e-03
# 19      Text_TrustPhys     no_system_prompt  t-test   2.306284  2.111931e-02
#
#     Significant
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16         True
# 17        False
# 18         True
# 19         True

# %%
sns.displot(
    D, x="Similarity", hue="Income", col="Question", 
    row="Condition", kind="hist", bins=50, 
    stat="probability", 
    multiple='dodge', shrink=1, 
    common_norm=False,
    facet_kws=dict(sharey=False),
    legend=False,
)
plt.xlim(0.0, 1.0)
plt.legend([0,1], title='Income', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)
# Out:
# C:\Users\howar\AppData\Local\Temp\ipykernel_62080\2664053132.py:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend([0,1], title='Income', loc='lower left', labels=['Privileged', "Protected"], bbox_to_anchor=(-1.5, -0.25), ncol=2)

# %%
import scipy.stats as stats
def perform_stat_test(data, group_var, value_var, test_type='t-test'):
    groups = data[group_var].unique()
    if len(groups) != 2:
        raise ValueError("Group variable must have exactly two unique values for this test.")
    group1 = data[data[group_var] == groups[0]][value_var]
    group2 = data[data[group_var] == groups[1]][value_var]
    mean1 = group1.mean()
    mean2 = group2.mean()
    if test_type == 't-test':
        stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)
    elif test_type == 'mannwhitney':
        stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    else:
        raise ValueError("Invalid test type specified.")
    return stat, p_value, mean1, mean2, groups[0], groups[1]

results = []

for question in D['Question'].unique():
    for condition in D['Condition'].unique():
        subset = D[(D['Question'] == question) & (D['Condition'] == condition)]
        if subset.empty:
            continue
        try:
            stat, p_value, mean1, mean2, group1_name, group2_name = perform_stat_test(
                subset, 'Income', 'Similarity', test_type='t-test')
            significant = p_value < 0.05  # Significance threshold
            higher_group = group1_name if mean1 > mean2 else group2_name
            results.append({
                'Question': question,
                'Condition': condition,
                'Test': 't-test',
                'Statistic': stat,
                'p-value': p_value,
                'Significant': significant,
                'Mean_{}'.format(group1_name): mean1,
                'Mean_{}'.format(group2_name): mean2,
                'Higher_Mean_Group': higher_group if significant else 'N/A'
            })
        except ValueError as e:
            print(f"Error for Question {question}, Condition {condition}: {e}")

results_df = pd.DataFrame(results)
results_df
# Out:
#               Question            Condition    Test  Statistic   p-value  \
# 0   Text_SubjectiveLit                all_4  t-test  -0.718481  0.472486
# 1   Text_SubjectiveLit  conditioning_on_all  t-test  -1.325604  0.185016
# 2   Text_SubjectiveLit              holdout  t-test  -1.159504  0.246261
# 3   Text_SubjectiveLit   Baseline Zero Shot  t-test  -2.605779  0.009187
# 4   Text_SubjectiveLit     no_system_prompt  t-test  -2.348235  0.018892
# 5         Text_Anxiety                all_4  t-test  -1.936801  0.052812
# 6         Text_Anxiety  conditioning_on_all  t-test  -2.879081  0.004001
# 7         Text_Anxiety              holdout  t-test  -3.622182  0.000293
# 8         Text_Anxiety   Baseline Zero Shot  t-test  -2.160292  0.030786
# 9         Text_Anxiety     no_system_prompt  t-test  -1.731793  0.083357
# 10       Text_Numeracy                all_4  t-test  -1.226228  0.220158
# 11       Text_Numeracy  conditioning_on_all  t-test   0.357194  0.720958
# 12       Text_Numeracy              holdout  t-test  -0.191757  0.847934
# 13       Text_Numeracy   Baseline Zero Shot  t-test  -1.986836  0.046982
# 14       Text_Numeracy     no_system_prompt  t-test  -0.303173  0.761768
# 15      Text_TrustPhys                all_4  t-test   1.734073  0.082952
# 16      Text_TrustPhys  conditioning_on_all  t-test  -0.269494  0.787558
# 17      Text_TrustPhys              holdout  t-test   2.510896  0.012049
# 18      Text_TrustPhys   Baseline Zero Shot  t-test  -0.921989  0.356568
# 19      Text_TrustPhys     no_system_prompt  t-test   0.255338  0.798470
#
#     Significant    Mean_0    Mean_1 Higher_Mean_Group
# 0         False  0.585485  0.588026               N/A
# 1         False  0.498103  0.502826               N/A
# 2         False  0.575672  0.577729               N/A
# 3          True  0.549934  0.558940                 1
# 4          True  0.584377  0.592443                 1
# 5         False  0.531936  0.539508               N/A
# 6          True  0.486603  0.497296                 1
# 7          True  0.513679  0.520655                 1
# 8          True  0.488540  0.496933                 1
# 9         False  0.501845  0.508422               N/A
# 10        False  0.289451  0.293663               N/A
# 11        False  0.227379  0.226304               N/A
# 12        False  0.283692  0.284011               N/A
# 13         True  0.237420  0.243498                 1
# 14        False  0.285069  0.286050               N/A
# 15        False  0.591465  0.584864               N/A
# 16        False  0.514929  0.515949               N/A
# 17         True  0.571449  0.566658                 0
# 18        False  0.511255  0.514784               N/A
# 19        False  0.562016  0.561053               N/A
